# %%
import sys
import tensorflow as tf

print(f"TensorFlow ver is {tf.__version__}")
print(f"PYTHON ver is {sys.version}")
print("GPU is","available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TensorFlow ver is 2.10.0
# PYTHON ver is 3.9.13 (tags/v3.9.13:6de2ca5, May 17 2022, 16:36:42) [MSC v.1929 64 bit (AMD64)]
# GPU is available

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import joblib
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# ============================================================
# 0) Config
# ============================================================
DATA_DIR = "database"
DATA_FILE = "cmall_remove_duplicate_m_all.csv"   # RAW(정규화 전) csv

QUALITY_MODEL_PATH = "best_model_residue.h5"      # pretrained quality ANN (frozen)
POLICY_SAVE_PATH   = "best_policy_net.keras"     # save trained policy net (Keras v3)

SCALER_X_PATH = "scaler_x_38.pkl"                # for quality inputs (38)
SCALER_Y_PATH = "scaler_y_1.pkl"                 # for residue (real unit)

RANDOM_STATE = 42
BATCH_SIZE = 1024
EPOCHS = 500

TARGET_RESIDUE_DEFAULT = 8.0

# Δu bound in normalized space (변수별로 튜닝 권장)
DELTA_MAX_DEFAULT = 0.02

# Loss weights (규제항)
LAM_L2 = 1.0
LAM_L1 = 0.1
HUBER_DELTA = 1.0

LR = 5e-4
PATIENCE = 50

# %%
# ============================================================
# 1) Column definitions
# ============================================================

CONTROL_COLS_9 = [
    "RP_roller_p1",
    "RP_roller_p2",
    "RP_sep_rpm",
    "RP_sep_fan_damper",
    "RP_sep_BF_damper",
    "mill_BF_damper",
    "mill_sep_rpm",
    "mill_sep_fan_damper",
    "grind_aid",
]
assert len(CONTROL_COLS_9) == 9

MONITOR_COLS_28 = [
    # existing monitoring (23)
    "RP_spac",
    "RP_skew",
    "RP_roller_energy1",
    "RP_roller_energy2",
    "RP_roller_vib",
    "RP_BE_energy1",
    "RP_BE_energy2",
    "RP_sep_BF_pressure",
    "dosing_BE_energy",
    "mill_feed_c",
    "mill_feed_cir",
    "mill_energy",
    "mill_in_temp",
    "mill_out_temp",
    "mill_BE_energy",
    "mill_out_gas_temp",
    "mill_out_mater_temp",
    "mill_BF_pressure",
    "mill_sep_BF_pressure",
    "mill_sep_BF_fan_damper",
    "final_BE_1",
    "final_BE_2",
    "final_mater_temp",
    # feed composition moved to monitoring (4)
    "feed_clinker",
    "feed_gypsum",
    "feed_slag",
    "feed_FA",
    # total feed moved to monitoring (1)
    "feed_total",
]
assert len(MONITOR_COLS_28) == 28

# ---- Quality vs Policy 품질 컬럼 분리
QUALITY_PREV_COL   = "residue_prev"   # quality ANN input
POLICY_CUR_COL     = "residue"        # policy ANN input (current quality)
TARGET_QUALITY_COL = "residue_target" # policy ANN input & training target (real unit)

# ---- Quality model input (MUST match pretrained quality model training)
QUALITY_INPUT_COLS = CONTROL_COLS_9 + MONITOR_COLS_28 + [QUALITY_PREV_COL]
assert len(QUALITY_INPUT_COLS) == 38

# ---- Policy input (NOW 39): monitor 28 + current_quality 1 + current_control 9 + target 1
POLICY_INPUT_DIM = 28 + 1 + 9 + 1
assert POLICY_INPUT_DIM == 39

print("QUALITY_INPUT_DIM:", len(QUALITY_INPUT_COLS))
print("POLICY_INPUT_DIM :", POLICY_INPUT_DIM)
# Out:
# QUALITY_INPUT_DIM: 38
# POLICY_INPUT_DIM : 39

# %%
# ============================================================
# 2) Load raw data
# ============================================================
csv_path = os.path.join(DATA_DIR, DATA_FILE)
df = pd.read_csv(csv_path)

# Ensure target column
if TARGET_QUALITY_COL not in df.columns:
    df[TARGET_QUALITY_COL] = TARGET_RESIDUE_DEFAULT

required_cols = list(set(
    QUALITY_INPUT_COLS +          # includes residue_prev
    [POLICY_CUR_COL] +            # includes residue
    [TARGET_QUALITY_COL]          # includes residue_target
))

missing_cols = [c for c in required_cols if c not in df.columns]
if missing_cols:
    raise ValueError(f"Missing columns in CSV: {missing_cols}")

df = df.dropna(subset=required_cols).reset_index(drop=True)
print(f"Loaded raw data: {df.shape} from {csv_path}")
print("Target unique count:", df[TARGET_QUALITY_COL].nunique())
# Out:
# Loaded raw data: (60632, 43) from database\cmall_remove_duplicate_m_all.csv
# Target unique count: 1

# %%
# ============================================================
# 3) Split indices
# ============================================================
idx_all = np.arange(len(df))
idx_train, idx_temp = train_test_split(idx_all, test_size=0.30, random_state=RANDOM_STATE)
idx_val, idx_test   = train_test_split(idx_temp, test_size=0.50, random_state=RANDOM_STATE)

print(f"Split: train={len(idx_train)}, val={len(idx_val)}, test={len(idx_test)}")
# Out:
# Split: train=42442, val=9095, test=9095

# %%
# ============================================================
# 4) Fit scalers (train only) & save
# ============================================================

# scaler_x: quality input 38개 (controls+monitor+residue_prev)
scaler_x = MinMaxScaler(feature_range=(0.0, 1.0))
scaler_x.fit(df.loc[idx_all, QUALITY_INPUT_COLS].to_numpy(dtype=np.float32))

# scaler_y: residue real unit (policy current/target, and inverse for printing)
scaler_y = MinMaxScaler(feature_range=(0.0, 1.0))
scaler_y.fit(df.loc[idx_all, [POLICY_CUR_COL]].to_numpy(dtype=np.float32))

joblib.dump(scaler_x, SCALER_X_PATH)
joblib.dump(scaler_y, SCALER_Y_PATH)

print("Saved scalers:", SCALER_X_PATH, SCALER_Y_PATH)
# Out:
# Saved scalers: scaler_x_38.pkl scaler_y_1.pkl

# %%
# ============================================================
# 5) Load pretrained quality model (FROZEN)
# ============================================================
quality_model = tf.keras.models.load_model(QUALITY_MODEL_PATH)
quality_model.trainable = False

print("Quality model input/output:", quality_model.input_shape, quality_model.output_shape)
# Out:
# Quality model input/output: (None, 38) (None, 1)

# %%
# ============================================================
# 6) Build normalized arrays for policy training (39(+1)-D)
# ============================================================

# ---- raw arrays
u_cur_raw  = df[CONTROL_COLS_9].to_numpy(dtype=np.float32)            # (N,9)
mon_raw    = df[MONITOR_COLS_28].to_numpy(dtype=np.float32)           # (N,28)
qprev_raw  = df[[QUALITY_PREV_COL]].to_numpy(dtype=np.float32)        # (N,1)  quality prev
qcur_raw   = df[[POLICY_CUR_COL]].to_numpy(dtype=np.float32)          # (N,1)  policy current
yT_raw     = df[[TARGET_QUALITY_COL]].to_numpy(dtype=np.float32)      # (N,1)  policy target

# ---- quality input raw (38): [u_cur, mon, qprev]
Xq_raw = np.concatenate([u_cur_raw, mon_raw, qprev_raw], axis=1)      # (N,38)

# ---- normalize quality input via scaler_x (0~1)
Xq_norm = scaler_x.transform(Xq_raw).astype(np.float32)               # (N,38)
u_cur_norm = Xq_norm[:, :9]                                           # (N,9)
mon_norm   = Xq_norm[:, 9:9+28]                                       # (N,28)
qprev_norm = Xq_norm[:, 9+28:9+28+1]                                  # (N,1) normalized residue_prev space

# ---- normalize policy current & target via scaler_y (0~1)
qcur_norm = scaler_y.transform(qcur_raw).astype(np.float32)           # (N,1)
yT_norm   = scaler_y.transform(yT_raw).astype(np.float32)             # (N,1)

# ---- policy input (39(+1)):
# [mon_norm(28), qcur_norm(1), u_cur_norm(9), yT_norm(1), qprev_norm(1)]
Xp = np.concatenate([mon_norm, qcur_norm, u_cur_norm, yT_norm, qprev_norm], axis=1).astype(np.float32)
assert Xp.shape[1] == POLICY_INPUT_DIM + 1

# ---- split
Xp_train, yT_train = Xp[idx_train], yT_norm[idx_train]
Xp_val,   yT_val   = Xp[idx_val],   yT_norm[idx_val]
Xp_test,  yT_test  = Xp[idx_test],  yT_norm[idx_test]

print("Policy arrays:",
      "train", Xp_train.shape, yT_train.shape,
      "| val", Xp_val.shape, yT_val.shape,
      "| test", Xp_test.shape, yT_test.shape)
# Out:
# Policy arrays: train (42442, 40) (42442, 1) | val (9095, 40) (9095, 1) | test (9095, 40) (9095, 1)

# %%
# ============================================================
# 7) tf.data datasets
# ============================================================
train_ds = tf.data.Dataset.from_tensor_slices((Xp_train, yT_train)) \
    .shuffle(20000, seed=RANDOM_STATE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((Xp_val, yT_val)) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((Xp_test, yT_test)) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

print("Datasets ready.")
# Out:
# Datasets ready.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout

# ============================================================
# 8) Build policy network (delta-u for 9 controls)
# ============================================================
def build_policy_model(input_shape):
    model = Sequential([
        Dense(256, activation='swish',
              kernel_initializer='glorot_uniform',
              input_shape=input_shape),
        BatchNormalization(),
        Dropout(0.1),

        Dense(256, activation='swish',
              kernel_initializer='glorot_uniform'),
        BatchNormalization(),
        Dropout(0.1),

        Dense(128, activation='swish',
              kernel_initializer='glorot_uniform'),
        BatchNormalization(),

        Dense(9, activation='tanh', name='delta_raw')  # in [-1, 1]
    ])
    return model

policy_net = build_policy_model((POLICY_INPUT_DIM,))
policy_net.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               10240
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  delta_raw (Dense)           (None, 9)                 1161
#
# =================================================================
# Total params: 112,649
# Trainable params: 111,369
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
# ============================================================
# 9) Delta bounds (per-control) in normalized space
# ============================================================
DELTA_MAX = np.array([DELTA_MAX_DEFAULT] * 9, dtype=np.float32)  # (9,)
DELTA_MAX_TF = tf.constant(DELTA_MAX.reshape(1, -1), dtype=tf.float32)

print("DELTA_MAX:", DELTA_MAX)
# Out:
# DELTA_MAX: [0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]

# %%
# ============================================================
# 10) Wrapper model: frozen quality model + trainable policy model
#     Xp layout (40):
#       [mon(28), qcur(1), u_cur(9), y_target(1), qprev(1)]
#     quality input (38):
#       [u_new(9), mon(28), qprev(1)]
# ============================================================
class ControlRecommender(tf.keras.Model):
    def __init__(self, policy_net: tf.keras.Model, quality_model: tf.keras.Model,
                 lam_l2: float = 1.0, lam_l1: float = 0.1, huber_delta: float = 1.0):
        super().__init__()
        self.policy_net = policy_net
        self.quality_model = quality_model  # frozen

        self.lam_l2 = lam_l2
        self.lam_l1 = lam_l1
        self.huber_delta = huber_delta

        self.loss_tracker = tf.keras.metrics.Mean(name="loss")
        self.pred_loss_tracker = tf.keras.metrics.Mean(name="pred_loss")
        self.delta_l2_tracker = tf.keras.metrics.Mean(name="delta_l2")
        self.delta_l1_tracker = tf.keras.metrics.Mean(name="delta_l1")

    @property
    def metrics(self):
        return [self.loss_tracker, self.pred_loss_tracker,
                self.delta_l2_tracker, self.delta_l1_tracker]

    def call(self, Xp_batch, training=False):
        # Xp layout
        mon   = Xp_batch[:, 0:28]
        qcur  = Xp_batch[:, 28:29]    # policy input only (not used in quality input)
        u_cur = Xp_batch[:, 29:38]
        yT    = Xp_batch[:, 38:39]    # policy input only (loss uses yT separately)
        qprev = Xp_batch[:, 39:40]    # IMPORTANT: quality input prev quality

        # policy input: qprev 제외한 39차원만 사용
        Xp_no_prev = Xp_batch[:, 0:39]  # = [mon(28), qcur(1), u_cur(9), yT(1)]

        # policy_net outputs delta_raw in [-1,1]
        delta_raw = self.policy_net(Xp_no_prev, training=training)  # (B,9)
        delta = delta_raw * DELTA_MAX_TF                          # bounded
        u_new = tf.clip_by_value(u_cur + delta, 0.0, 1.0)         # (B,9)

        # quality input (38): [u_new(9), mon(28), qprev(1)]
        Xq_new = tf.concat([u_new, mon, qprev], axis=1)           # (B,38)
        y_pred = self.quality_model(Xq_new, training=False)       # (B,1)

        return u_new, y_pred, delta

    def train_step(self, data):
        Xp_batch, y_target_batch = data

        with tf.GradientTape() as tape:
            _, y_pred, delta = self(Xp_batch, training=True)

            pred_loss = tf.reduce_mean(
                tf.keras.losses.huber(y_target_batch, y_pred, delta=self.huber_delta)
            )

            delta_l2 = tf.reduce_mean(tf.reduce_sum(tf.square(delta), axis=1))
            delta_l1 = tf.reduce_mean(tf.reduce_sum(tf.abs(delta), axis=1))

            loss = pred_loss + self.lam_l2 * delta_l2 + self.lam_l1 * delta_l1

        grads = tape.gradient(loss, self.policy_net.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.policy_net.trainable_variables))

        self.loss_tracker.update_state(loss)
        self.pred_loss_tracker.update_state(pred_loss)
        self.delta_l2_tracker.update_state(delta_l2)
        self.delta_l1_tracker.update_state(delta_l1)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        Xp_batch, y_target_batch = data

        _, y_pred, delta = self(Xp_batch, training=False)

        pred_loss = tf.reduce_mean(
            tf.keras.losses.huber(y_target_batch, y_pred, delta=self.huber_delta)
        )
        delta_l2 = tf.reduce_mean(tf.reduce_sum(tf.square(delta), axis=1))
        delta_l1 = tf.reduce_mean(tf.reduce_sum(tf.abs(delta), axis=1))

        loss = pred_loss + self.lam_l2 * delta_l2 + self.lam_l1 * delta_l1

        self.loss_tracker.update_state(loss)
        self.pred_loss_tracker.update_state(pred_loss)
        self.delta_l2_tracker.update_state(delta_l2)
        self.delta_l1_tracker.update_state(delta_l1)

        return {m.name: m.result() for m in self.metrics}

# %%
# ============================================================
# 11) Train policy (recommender)
# ============================================================
quality_model.trainable = False

recommender = ControlRecommender(
    policy_net=policy_net,
    quality_model=quality_model,
    lam_l2=LAM_L2,
    lam_l1=LAM_L1,
    huber_delta=HUBER_DELTA
)

recommender.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LR))

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=PATIENCE, restore_best_weights=True
)

history = recommender.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[early_stop],
    verbose=1
)

print("\nEvaluation on test set:")
recommender.evaluate(test_ds, verbose=1)

# ---- Save ONLY policy_net (권장)
policy_net.save(POLICY_SAVE_PATH)
print("Saved policy_net to:", POLICY_SAVE_PATH)
# Out:
# Epoch 1/500
# 42/42 [==============================] - 4s 29ms/step - loss: 0.0136 - pred_loss: 0.0057 - delta_l2: 8.3945e-04 - delta_l1: 0.0709 - val_loss: 0.0074 - val_pred_loss: 0.0066 - val_delta_l2: 1.1371e-05 - val_delta_l1: 0.0078
# Epoch 2/500
# 42/42 [==============================] - 1s 16ms/step - loss: 0.0096 - pred_loss: 0.0057 - delta_l2: 2.7992e-04 - delta_l1: 0.0367 - val_loss: 0.0074 - val_pred_loss: 0.0066 - val_delta_l2: 1.2443e-05 - val_delta_l1: 0.0085
# Epoch 3/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0085 - pred_loss: 0.0058 - delta_l2: 1.6656e-04 - delta_l1: 0.0260 - val_loss: 0.0071 - val_pred_loss: 0.0066 - val_delta_l2: 4.0583e-06 - val_delta_l1: 0.0051
# Epoch 4/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0080 - pred_loss: 0.0058 - delta_l2: 1.2284e-04 - delta_l1: 0.0208 - val_loss: 0.0070 - val_pred_loss: 0.0066 - val_delta_l2: 2.9782e-06 - val_delta_l1: 0.0043
# Epoch 5/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0077 - pred_loss: 0.0058 - delta_l2: 1.0229e-04 - delta_l1: 0.0176 - val_loss: 0.0071 - val_pred_loss: 0.0066 - val_delta_l2: 4.6263e-06 - val_delta_l1: 0.0053
# Epoch 6/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0075 - pred_loss: 0.0058 - delta_l2: 8.9574e-05 - delta_l1: 0.0154 - val_loss: 0.0072 - val_pred_loss: 0.0066 - val_delta_l2: 5.4230e-06 - val_delta_l1: 0.0059
# Epoch 7/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0073 - pred_loss: 0.0059 - delta_l2: 8.1908e-05 - delta_l1: 0.0138 - val_loss: 0.0072 - val_pred_loss: 0.0066 - val_delta_l2: 4.7276e-06 - val_delta_l1: 0.0056
# Epoch 8/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0072 - pred_loss: 0.0059 - delta_l2: 7.6119e-05 - delta_l1: 0.0126 - val_loss: 0.0071 - val_pred_loss: 0.0066 - val_delta_l2: 3.7179e-06 - val_delta_l1: 0.0049
# Epoch 9/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0071 - pred_loss: 0.0059 - delta_l2: 7.2743e-05 - delta_l1: 0.0116 - val_loss: 0.0070 - val_pred_loss: 0.0066 - val_delta_l2: 3.4536e-06 - val_delta_l1: 0.0043
# Epoch 10/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0070 - pred_loss: 0.0059 - delta_l2: 7.0515e-05 - delta_l1: 0.0108 - val_loss: 0.0069 - val_pred_loss: 0.0065 - val_delta_l2: 4.0115e-06 - val_delta_l1: 0.0039
# Epoch 11/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0070 - pred_loss: 0.0059 - delta_l2: 6.9287e-05 - delta_l1: 0.0103 - val_loss: 0.0068 - val_pred_loss: 0.0065 - val_delta_l2: 6.4873e-06 - val_delta_l1: 0.0038
# Epoch 12/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0069 - pred_loss: 0.0059 - delta_l2: 6.6660e-05 - delta_l1: 0.0097 - val_loss: 0.0068 - val_pred_loss: 0.0064 - val_delta_l2: 1.1160e-05 - val_delta_l1: 0.0040
# Epoch 13/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0069 - pred_loss: 0.0059 - delta_l2: 6.5982e-05 - delta_l1: 0.0092 - val_loss: 0.0067 - val_pred_loss: 0.0063 - val_delta_l2: 1.7163e-05 - val_delta_l1: 0.0043
# Epoch 14/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0068 - pred_loss: 0.0059 - delta_l2: 6.5088e-05 - delta_l1: 0.0089 - val_loss: 0.0067 - val_pred_loss: 0.0062 - val_delta_l2: 2.7100e-05 - val_delta_l1: 0.0053
# Epoch 15/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0068 - pred_loss: 0.0059 - delta_l2: 6.3667e-05 - delta_l1: 0.0084 - val_loss: 0.0067 - val_pred_loss: 0.0061 - val_delta_l2: 3.5091e-05 - val_delta_l1: 0.0053
# Epoch 16/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0068 - pred_loss: 0.0059 - delta_l2: 6.4746e-05 - delta_l1: 0.0082 - val_loss: 0.0066 - val_pred_loss: 0.0060 - val_delta_l2: 4.3548e-05 - val_delta_l1: 0.0057
# Epoch 17/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0067 - pred_loss: 0.0059 - delta_l2: 6.3588e-05 - delta_l1: 0.0079 - val_loss: 0.0066 - val_pred_loss: 0.0060 - val_delta_l2: 5.1803e-05 - val_delta_l1: 0.0063
# Epoch 18/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0067 - pred_loss: 0.0059 - delta_l2: 6.4115e-05 - delta_l1: 0.0078 - val_loss: 0.0066 - val_pred_loss: 0.0059 - val_delta_l2: 5.5183e-05 - val_delta_l1: 0.0062
# Epoch 19/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0067 - pred_loss: 0.0059 - delta_l2: 6.4030e-05 - delta_l1: 0.0076 - val_loss: 0.0066 - val_pred_loss: 0.0059 - val_delta_l2: 6.2718e-05 - val_delta_l1: 0.0067
# Epoch 20/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0067 - pred_loss: 0.0059 - delta_l2: 6.4203e-05 - delta_l1: 0.0075 - val_loss: 0.0066 - val_pred_loss: 0.0059 - val_delta_l2: 6.8716e-05 - val_delta_l1: 0.0072
# Epoch 21/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0067 - pred_loss: 0.0059 - delta_l2: 6.4036e-05 - delta_l1: 0.0073 - val_loss: 0.0066 - val_pred_loss: 0.0059 - val_delta_l2: 6.5512e-05 - val_delta_l1: 0.0068
# Epoch 22/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0067 - pred_loss: 0.0059 - delta_l2: 6.3614e-05 - delta_l1: 0.0071 - val_loss: 0.0066 - val_pred_loss: 0.0059 - val_delta_l2: 6.8156e-05 - val_delta_l1: 0.0067
# Epoch 23/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.3718e-05 - delta_l1: 0.0069 - val_loss: 0.0066 - val_pred_loss: 0.0059 - val_delta_l2: 6.8620e-05 - val_delta_l1: 0.0066
# Epoch 24/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.3747e-05 - delta_l1: 0.0068 - val_loss: 0.0066 - val_pred_loss: 0.0058 - val_delta_l2: 7.0610e-05 - val_delta_l1: 0.0067
# Epoch 25/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.4202e-05 - delta_l1: 0.0067 - val_loss: 0.0066 - val_pred_loss: 0.0058 - val_delta_l2: 7.1628e-05 - val_delta_l1: 0.0067
# Epoch 26/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.4288e-05 - delta_l1: 0.0067 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.8929e-05 - val_delta_l1: 0.0063
# Epoch 27/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.3876e-05 - delta_l1: 0.0065 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 6.8026e-05 - val_delta_l1: 0.0063
# Epoch 28/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.4724e-05 - delta_l1: 0.0065 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 6.7512e-05 - val_delta_l1: 0.0061
# Epoch 29/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.3965e-05 - delta_l1: 0.0064 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.8352e-05 - val_delta_l1: 0.0061
# Epoch 30/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.4203e-05 - delta_l1: 0.0063 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 7.0898e-05 - val_delta_l1: 0.0062
# Epoch 31/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.4491e-05 - delta_l1: 0.0063 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 6.6755e-05 - val_delta_l1: 0.0059
# Epoch 32/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.4386e-05 - delta_l1: 0.0062 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.8739e-05 - val_delta_l1: 0.0059
# Epoch 33/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0066 - pred_loss: 0.0059 - delta_l2: 6.4528e-05 - delta_l1: 0.0061 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 7.0968e-05 - val_delta_l1: 0.0060
# Epoch 34/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.4863e-05 - delta_l1: 0.0061 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 6.8067e-05 - val_delta_l1: 0.0059
# Epoch 35/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5277e-05 - delta_l1: 0.0061 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.9460e-05 - val_delta_l1: 0.0060
# Epoch 36/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.4741e-05 - delta_l1: 0.0059 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.9300e-05 - val_delta_l1: 0.0057
# Epoch 37/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5538e-05 - delta_l1: 0.0060 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 6.7571e-05 - val_delta_l1: 0.0058
# Epoch 38/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5394e-05 - delta_l1: 0.0060 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.8576e-05 - val_delta_l1: 0.0056
# Epoch 39/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5656e-05 - delta_l1: 0.0060 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 6.7001e-05 - val_delta_l1: 0.0058
# Epoch 40/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5286e-05 - delta_l1: 0.0059 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.6509e-05 - val_delta_l1: 0.0056
# Epoch 41/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.5358e-05 - delta_l1: 0.0058 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.7125e-05 - val_delta_l1: 0.0057
# Epoch 42/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5591e-05 - delta_l1: 0.0058 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 6.2120e-05 - val_delta_l1: 0.0053
# Epoch 43/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5698e-05 - delta_l1: 0.0058 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 6.5723e-05 - val_delta_l1: 0.0053
# Epoch 44/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5605e-05 - delta_l1: 0.0058 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.7245e-05 - val_delta_l1: 0.0054
# Epoch 45/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6442e-05 - delta_l1: 0.0059 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 7.0384e-05 - val_delta_l1: 0.0058
# Epoch 46/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5477e-05 - delta_l1: 0.0058 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.9190e-05 - val_delta_l1: 0.0057
# Epoch 47/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.5681e-05 - delta_l1: 0.0057 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 6.6478e-05 - val_delta_l1: 0.0055
# Epoch 48/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5780e-05 - delta_l1: 0.0057 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.8338e-05 - val_delta_l1: 0.0055
# Epoch 49/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5902e-05 - delta_l1: 0.0057 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.8481e-05 - val_delta_l1: 0.0054
# Epoch 50/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.6119e-05 - delta_l1: 0.0056 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 7.3317e-05 - val_delta_l1: 0.0058
# Epoch 51/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.6351e-05 - delta_l1: 0.0056 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 6.4766e-05 - val_delta_l1: 0.0051
# Epoch 52/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6377e-05 - delta_l1: 0.0057 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 7.0425e-05 - val_delta_l1: 0.0059
# Epoch 53/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6457e-05 - delta_l1: 0.0057 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 6.0825e-05 - val_delta_l1: 0.0049
# Epoch 54/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0059 - delta_l2: 6.5643e-05 - delta_l1: 0.0056 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 6.5386e-05 - val_delta_l1: 0.0053
# Epoch 55/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6033e-05 - delta_l1: 0.0056 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 5.8031e-05 - val_delta_l1: 0.0049
# Epoch 56/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6040e-05 - delta_l1: 0.0056 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 5.9891e-05 - val_delta_l1: 0.0051
# Epoch 57/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6168e-05 - delta_l1: 0.0056 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 6.2380e-05 - val_delta_l1: 0.0050
# Epoch 58/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.5825e-05 - delta_l1: 0.0056 - val_loss: 0.0065 - val_pred_loss: 0.0059 - val_delta_l2: 6.1270e-05 - val_delta_l1: 0.0052
# Epoch 59/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6330e-05 - delta_l1: 0.0056 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 6.4561e-05 - val_delta_l1: 0.0053
# Epoch 60/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6783e-05 - delta_l1: 0.0056 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 6.1928e-05 - val_delta_l1: 0.0050
# Epoch 61/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6219e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.8484e-05 - val_delta_l1: 0.0052
# Epoch 62/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6384e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.8313e-05 - val_delta_l1: 0.0054
# Epoch 63/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6660e-05 - delta_l1: 0.0056 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.9726e-05 - val_delta_l1: 0.0056
# Epoch 64/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7005e-05 - delta_l1: 0.0055 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.9042e-05 - val_delta_l1: 0.0055
# Epoch 65/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.6789e-05 - delta_l1: 0.0056 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.4685e-05 - val_delta_l1: 0.0058
# Epoch 66/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6889e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.3502e-05 - val_delta_l1: 0.0055
# Epoch 67/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7126e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.0315e-05 - val_delta_l1: 0.0054
# Epoch 68/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6519e-05 - delta_l1: 0.0055 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 7.0464e-05 - val_delta_l1: 0.0057
# Epoch 69/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.7105e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.8293e-05 - val_delta_l1: 0.0052
# Epoch 70/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7065e-05 - delta_l1: 0.0055 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 6.6186e-05 - val_delta_l1: 0.0058
# Epoch 71/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.7605e-05 - delta_l1: 0.0056 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 6.3050e-05 - val_delta_l1: 0.0050
# Epoch 72/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6775e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5732e-05 - val_delta_l1: 0.0053
# Epoch 73/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7368e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 6.0269e-05 - val_delta_l1: 0.0049
# Epoch 74/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6827e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 5.4546e-05 - val_delta_l1: 0.0046
# Epoch 75/500
# 42/42 [==============================] - 1s 31ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7208e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 5.4143e-05 - val_delta_l1: 0.0044
# Epoch 76/500
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7868e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.4075e-05 - val_delta_l1: 0.0049
# Epoch 77/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.7094e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.4980e-05 - val_delta_l1: 0.0057
# Epoch 78/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7229e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.8620e-05 - val_delta_l1: 0.0057
# Epoch 79/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7292e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.0262e-05 - val_delta_l1: 0.0054
# Epoch 80/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7096e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.5022e-05 - val_delta_l1: 0.0056
# Epoch 81/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0065 - pred_loss: 0.0058 - delta_l2: 6.7671e-05 - delta_l1: 0.0056 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.6666e-05 - val_delta_l1: 0.0058
# Epoch 82/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7252e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.7224e-05 - val_delta_l1: 0.0058
# Epoch 83/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7046e-05 - delta_l1: 0.0054 - val_loss: 0.0065 - val_pred_loss: 0.0058 - val_delta_l2: 7.7238e-05 - val_delta_l1: 0.0061
# Epoch 84/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7075e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.6351e-05 - val_delta_l1: 0.0057
# Epoch 85/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7008e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5464e-05 - val_delta_l1: 0.0053
# Epoch 86/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6852e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.1972e-05 - val_delta_l1: 0.0056
# Epoch 87/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.7052e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.7041e-05 - val_delta_l1: 0.0051
# Epoch 88/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6443e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.7049e-05 - val_delta_l1: 0.0051
# Epoch 89/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6652e-05 - delta_l1: 0.0054 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.7454e-05 - val_delta_l1: 0.0051
# Epoch 90/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6095e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.9615e-05 - val_delta_l1: 0.0054
# Epoch 91/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6209e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.3664e-05 - val_delta_l1: 0.0050
# Epoch 92/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5952e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.1579e-05 - val_delta_l1: 0.0055
# Epoch 93/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6138e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.1326e-05 - val_delta_l1: 0.0055
# Epoch 94/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.6064e-05 - delta_l1: 0.0055 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.2975e-05 - val_delta_l1: 0.0056
# Epoch 95/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5781e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.9527e-05 - val_delta_l1: 0.0052
# Epoch 96/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5300e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5984e-05 - val_delta_l1: 0.0052
# Epoch 97/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5382e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.8073e-05 - val_delta_l1: 0.0051
# Epoch 98/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5684e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.6450e-05 - val_delta_l1: 0.0055
# Epoch 99/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5743e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.7521e-05 - val_delta_l1: 0.0052
# Epoch 100/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5814e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.3499e-05 - val_delta_l1: 0.0051
# Epoch 101/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5497e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.1275e-05 - val_delta_l1: 0.0050
# Epoch 102/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5228e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5229e-05 - val_delta_l1: 0.0051
# Epoch 103/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4983e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.9497e-05 - val_delta_l1: 0.0054
# Epoch 104/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4579e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.9486e-05 - val_delta_l1: 0.0053
# Epoch 105/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4384e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5300e-05 - val_delta_l1: 0.0051
# Epoch 106/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4872e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 6.0477e-05 - val_delta_l1: 0.0049
# Epoch 107/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4568e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.4388e-05 - val_delta_l1: 0.0049
# Epoch 108/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5132e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5069e-05 - val_delta_l1: 0.0051
# Epoch 109/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4457e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.0578e-05 - val_delta_l1: 0.0055
# Epoch 110/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4668e-05 - delta_l1: 0.0053 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.6233e-05 - val_delta_l1: 0.0052
# Epoch 111/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4614e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.9755e-05 - val_delta_l1: 0.0054
# Epoch 112/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4490e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5896e-05 - val_delta_l1: 0.0052
# Epoch 113/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3625e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.3492e-05 - val_delta_l1: 0.0056
# Epoch 114/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3838e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.1939e-05 - val_delta_l1: 0.0056
# Epoch 115/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4277e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.6281e-05 - val_delta_l1: 0.0054
# Epoch 116/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3806e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5668e-05 - val_delta_l1: 0.0051
# Epoch 117/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4073e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.2203e-05 - val_delta_l1: 0.0049
# Epoch 118/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3919e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.1045e-05 - val_delta_l1: 0.0047
# Epoch 119/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3959e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.0023e-05 - val_delta_l1: 0.0048
# Epoch 120/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3686e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 5.9047e-05 - val_delta_l1: 0.0046
# Epoch 121/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3862e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 5.9665e-05 - val_delta_l1: 0.0047
# Epoch 122/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4138e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 5.6401e-05 - val_delta_l1: 0.0044
# Epoch 123/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4317e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.7875e-05 - val_delta_l1: 0.0053
# Epoch 124/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3391e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.0599e-05 - val_delta_l1: 0.0055
# Epoch 125/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4433e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.3003e-05 - val_delta_l1: 0.0049
# Epoch 126/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3601e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.6498e-05 - val_delta_l1: 0.0050
# Epoch 127/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3908e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 5.8960e-05 - val_delta_l1: 0.0046
# Epoch 128/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4273e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 5.7019e-05 - val_delta_l1: 0.0044
# Epoch 129/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3958e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 5.9832e-05 - val_delta_l1: 0.0047
# Epoch 130/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4111e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.7210e-05 - val_delta_l1: 0.0053
# Epoch 131/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3980e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.2475e-05 - val_delta_l1: 0.0048
# Epoch 132/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4090e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.7724e-05 - val_delta_l1: 0.0051
# Epoch 133/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3795e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.1114e-05 - val_delta_l1: 0.0047
# Epoch 134/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4124e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.3353e-05 - val_delta_l1: 0.0049
# Epoch 135/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4192e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.6228e-05 - val_delta_l1: 0.0049
# Epoch 136/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3795e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.1654e-05 - val_delta_l1: 0.0049
# Epoch 137/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3298e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5229e-05 - val_delta_l1: 0.0050
# Epoch 138/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3851e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 5.9166e-05 - val_delta_l1: 0.0046
# Epoch 139/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4175e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.1167e-05 - val_delta_l1: 0.0046
# Epoch 140/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4332e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5838e-05 - val_delta_l1: 0.0050
# Epoch 141/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4064e-05 - delta_l1: 0.0052 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 7.1972e-05 - val_delta_l1: 0.0055
# Epoch 142/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3791e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5234e-05 - val_delta_l1: 0.0051
# Epoch 143/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3536e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.0695e-05 - val_delta_l1: 0.0048
# Epoch 144/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4236e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7190e-05 - val_delta_l1: 0.0050
# Epoch 145/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4255e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.9586e-05 - val_delta_l1: 0.0055
# Epoch 146/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3915e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.4183e-05 - val_delta_l1: 0.0050
# Epoch 147/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4407e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.1841e-05 - val_delta_l1: 0.0049
# Epoch 148/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4633e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7757e-05 - val_delta_l1: 0.0049
# Epoch 149/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3651e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.3733e-05 - val_delta_l1: 0.0050
# Epoch 150/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4227e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.4773e-05 - val_delta_l1: 0.0050
# Epoch 151/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3838e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.5882e-05 - val_delta_l1: 0.0049
# Epoch 152/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3663e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 5.6427e-05 - val_delta_l1: 0.0045
# Epoch 153/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3569e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 5.8619e-05 - val_delta_l1: 0.0044
# Epoch 154/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3946e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 5.8100e-05 - val_delta_l1: 0.0047
# Epoch 155/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3846e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.9315e-05 - val_delta_l1: 0.0050
# Epoch 156/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4746e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7807e-05 - val_delta_l1: 0.0050
# Epoch 157/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4285e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5190e-05 - val_delta_l1: 0.0050
# Epoch 158/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4508e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 5.7291e-05 - val_delta_l1: 0.0046
# Epoch 159/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4231e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.8830e-05 - val_delta_l1: 0.0051
# Epoch 160/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3923e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7414e-05 - val_delta_l1: 0.0049
# Epoch 161/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4490e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.8791e-05 - val_delta_l1: 0.0052
# Epoch 162/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4368e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.6330e-05 - val_delta_l1: 0.0052
# Epoch 163/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4349e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.6765e-05 - val_delta_l1: 0.0050
# Epoch 164/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4290e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.9762e-05 - val_delta_l1: 0.0050
# Epoch 165/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4686e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.4860e-05 - val_delta_l1: 0.0047
# Epoch 166/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5268e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5282e-05 - val_delta_l1: 0.0051
# Epoch 167/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4613e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.5636e-05 - val_delta_l1: 0.0050
# Epoch 168/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4989e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.3677e-05 - val_delta_l1: 0.0050
# Epoch 169/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4526e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.1699e-05 - val_delta_l1: 0.0047
# Epoch 170/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4539e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.4393e-05 - val_delta_l1: 0.0050
# Epoch 171/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4642e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6191e-05 - val_delta_l1: 0.0048
# Epoch 172/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3552e-05 - delta_l1: 0.0049 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.4477e-05 - val_delta_l1: 0.0050
# Epoch 173/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4837e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.3691e-05 - val_delta_l1: 0.0048
# Epoch 174/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4418e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 5.8852e-05 - val_delta_l1: 0.0045
# Epoch 175/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4051e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0059 - val_delta_l2: 5.6556e-05 - val_delta_l1: 0.0044
# Epoch 176/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4615e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 5.7498e-05 - val_delta_l1: 0.0044
# Epoch 177/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5267e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7202e-05 - val_delta_l1: 0.0050
# Epoch 178/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4812e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.4966e-05 - val_delta_l1: 0.0050
# Epoch 179/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.5171e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6450e-05 - val_delta_l1: 0.0048
# Epoch 180/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5115e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.8837e-05 - val_delta_l1: 0.0053
# Epoch 181/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4942e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6182e-05 - val_delta_l1: 0.0048
# Epoch 182/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4894e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0057 - val_delta_l2: 7.3469e-05 - val_delta_l1: 0.0054
# Epoch 183/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4530e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6003e-05 - val_delta_l1: 0.0049
# Epoch 184/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.3906e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.2594e-05 - val_delta_l1: 0.0048
# Epoch 185/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4753e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.1753e-05 - val_delta_l1: 0.0048
# Epoch 186/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4284e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.1855e-05 - val_delta_l1: 0.0046
# Epoch 187/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4709e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.3324e-05 - val_delta_l1: 0.0047
# Epoch 188/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4484e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6815e-05 - val_delta_l1: 0.0049
# Epoch 189/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4450e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.9553e-05 - val_delta_l1: 0.0054
# Epoch 190/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4563e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.2116e-05 - val_delta_l1: 0.0047
# Epoch 191/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5258e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.2276e-05 - val_delta_l1: 0.0046
# Epoch 192/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4921e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 5.8808e-05 - val_delta_l1: 0.0044
# Epoch 193/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4876e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.0277e-05 - val_delta_l1: 0.0047
# Epoch 194/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4340e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.9962e-05 - val_delta_l1: 0.0053
# Epoch 195/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4562e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.8718e-05 - val_delta_l1: 0.0051
# Epoch 196/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.5326e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7464e-05 - val_delta_l1: 0.0049
# Epoch 197/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4389e-05 - delta_l1: 0.0050 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.8173e-05 - val_delta_l1: 0.0051
# Epoch 198/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4164e-05 - delta_l1: 0.0049 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.3362e-05 - val_delta_l1: 0.0047
# Epoch 199/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.5729e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.3469e-05 - val_delta_l1: 0.0047
# Epoch 200/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0064 - pred_loss: 0.0058 - delta_l2: 6.4501e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.2486e-05 - val_delta_l1: 0.0047
# Epoch 201/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.5117e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.8160e-05 - val_delta_l1: 0.0052
# Epoch 202/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0058 - delta_l2: 6.4709e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7488e-05 - val_delta_l1: 0.0050
# Epoch 203/500
# ...
# Epoch 351/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7542e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.9333e-05 - val_delta_l1: 0.0049
# Epoch 352/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8018e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.9219e-05 - val_delta_l1: 0.0055
# Epoch 353/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7370e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6243e-05 - val_delta_l1: 0.0048
# Epoch 354/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7099e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6578e-05 - val_delta_l1: 0.0048
# Epoch 355/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7580e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 5.7009e-05 - val_delta_l1: 0.0042
# Epoch 356/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8395e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7171e-05 - val_delta_l1: 0.0052
# Epoch 357/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7701e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.8731e-05 - val_delta_l1: 0.0048
# Epoch 358/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8038e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.3065e-05 - val_delta_l1: 0.0046
# Epoch 359/500
# 42/42 [==============================] - 1s 30ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7986e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.9970e-05 - val_delta_l1: 0.0051
# Epoch 360/500
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7921e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.1026e-05 - val_delta_l1: 0.0054
# Epoch 361/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7753e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.1478e-05 - val_delta_l1: 0.0053
# Epoch 362/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8452e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7553e-05 - val_delta_l1: 0.0049
# Epoch 363/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8843e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.0681e-05 - val_delta_l1: 0.0050
# Epoch 364/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8103e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.3690e-05 - val_delta_l1: 0.0051
# Epoch 365/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8090e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.3037e-05 - val_delta_l1: 0.0050
# Epoch 366/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8613e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6046e-05 - val_delta_l1: 0.0048
# Epoch 367/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8137e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.9120e-05 - val_delta_l1: 0.0049
# Epoch 368/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8456e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.0794e-05 - val_delta_l1: 0.0044
# Epoch 369/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8488e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.7234e-05 - val_delta_l1: 0.0057
# Epoch 370/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8085e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.1531e-05 - val_delta_l1: 0.0053
# Epoch 371/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8402e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7196e-05 - val_delta_l1: 0.0049
# Epoch 372/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8337e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.4468e-05 - val_delta_l1: 0.0046
# Epoch 373/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7216e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7549e-05 - val_delta_l1: 0.0050
# Epoch 374/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8111e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.8498e-05 - val_delta_l1: 0.0051
# Epoch 375/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8497e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.9432e-05 - val_delta_l1: 0.0053
# Epoch 376/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.9040e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.5095e-05 - val_delta_l1: 0.0049
# Epoch 377/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8481e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 5.9513e-05 - val_delta_l1: 0.0044
# Epoch 378/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7948e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.2508e-05 - val_delta_l1: 0.0053
# Epoch 379/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8415e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 5.9879e-05 - val_delta_l1: 0.0043
# Epoch 380/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8735e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.5955e-05 - val_delta_l1: 0.0046
# Epoch 381/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8444e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6474e-05 - val_delta_l1: 0.0048
# Epoch 382/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8234e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.4366e-05 - val_delta_l1: 0.0047
# Epoch 383/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8480e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.1937e-05 - val_delta_l1: 0.0052
# Epoch 384/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8253e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.3782e-05 - val_delta_l1: 0.0054
# Epoch 385/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7891e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.3291e-05 - val_delta_l1: 0.0048
# Epoch 386/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7950e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.3912e-05 - val_delta_l1: 0.0046
# Epoch 387/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8370e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.0319e-05 - val_delta_l1: 0.0050
# Epoch 388/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7721e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.2913e-05 - val_delta_l1: 0.0051
# Epoch 389/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7629e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 5.8605e-05 - val_delta_l1: 0.0043
# Epoch 390/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7615e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.7494e-05 - val_delta_l1: 0.0049
# Epoch 391/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7818e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.0312e-05 - val_delta_l1: 0.0053
# Epoch 392/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8101e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.9161e-05 - val_delta_l1: 0.0051
# Epoch 393/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7083e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.0686e-05 - val_delta_l1: 0.0045
# Epoch 394/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8127e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.4777e-05 - val_delta_l1: 0.0051
# Epoch 395/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7928e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.8144e-05 - val_delta_l1: 0.0050
# Epoch 396/500
# 42/42 [==============================] - 1s 34ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8475e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.0335e-05 - val_delta_l1: 0.0054
# Epoch 397/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7890e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.5273e-05 - val_delta_l1: 0.0047
# Epoch 398/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8491e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.9515e-05 - val_delta_l1: 0.0050
# Epoch 399/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7723e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.0895e-05 - val_delta_l1: 0.0051
# Epoch 400/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7484e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 5.9013e-05 - val_delta_l1: 0.0044
# Epoch 401/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7599e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.3118e-05 - val_delta_l1: 0.0047
# Epoch 402/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8085e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.3206e-05 - val_delta_l1: 0.0052
# Epoch 403/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7715e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.7724e-05 - val_delta_l1: 0.0049
# Epoch 404/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7806e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 8.0352e-05 - val_delta_l1: 0.0057
# Epoch 405/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7908e-05 - delta_l1: 0.0050 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.9042e-05 - val_delta_l1: 0.0051
# Epoch 406/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7932e-05 - delta_l1: 0.0051 - val_loss: 0.0064 - val_pred_loss: 0.0058 - val_delta_l2: 6.6517e-05 - val_delta_l1: 0.0052
# Epoch 407/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8161e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.1506e-05 - val_delta_l1: 0.0053
# Epoch 408/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8483e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6455e-05 - val_delta_l1: 0.0048
# Epoch 409/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8690e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 5.7486e-05 - val_delta_l1: 0.0042
# Epoch 410/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7919e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.6100e-05 - val_delta_l1: 0.0050
# Epoch 411/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7165e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 6.6973e-05 - val_delta_l1: 0.0051
# Epoch 412/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7600e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0058 - val_delta_l2: 6.7876e-05 - val_delta_l1: 0.0049
# Epoch 413/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7581e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.0578e-05 - val_delta_l1: 0.0051
# Epoch 414/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.7727e-05 - delta_l1: 0.0051 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.1628e-05 - val_delta_l1: 0.0053
# Epoch 415/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0063 - pred_loss: 0.0057 - delta_l2: 6.8343e-05 - delta_l1: 0.0052 - val_loss: 0.0063 - val_pred_loss: 0.0057 - val_delta_l2: 7.5233e-05 - val_delta_l1: 0.0054
#
# Evaluation on test set:
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0062 - pred_loss: 0.0056 - delta_l2: 7.2620e-05 - delta_l1: 0.0050
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved policy_net to: best_policy_net.keras

# %%
# ============================================================
# 12) Plot training curves
# ============================================================
hist = history.history

plt.figure(figsize=(10,5))
plt.plot(hist["loss"], label="train total loss")
plt.plot(hist["val_loss"], label="val total loss")
plt.title("Policy training - Total Loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# pred_loss도 기록되어 있으면 같이 출력
if "pred_loss" in hist:
    plt.figure(figsize=(10,5))
    plt.plot(hist["pred_loss"], label="train pred_loss")
    plt.plot(hist.get("val_pred_loss", []), label="val pred_loss")
    plt.title("Policy training - Prediction Loss (Huber)")
    plt.xlabel("epoch")
    plt.ylabel("pred_loss")
    plt.legend()
    plt.show()

# 규제항도 기록되어 있으면 출력
if "delta_l2" in hist:
    plt.figure(figsize=(10,5))
    plt.plot(hist["delta_l2"], label="train delta_l2")
    plt.plot(hist.get("val_delta_l2", []), label="val delta_l2")
    plt.title("Delta L2")
    plt.xlabel("epoch")
    plt.ylabel("delta_l2")
    plt.legend()
    plt.show()

if "delta_l1" in hist:
    plt.figure(figsize=(10,5))
    plt.plot(hist["delta_l1"], label="train delta_l1")
    plt.plot(hist.get("val_delta_l1", []), label="val delta_l1")
    plt.title("Delta L1")
    plt.xlabel("epoch")
    plt.ylabel("delta_l1")
    plt.legend()
    plt.show()

# %%
# ============================================================
# 13) Quick reload check
# ============================================================
policy_net_loaded = tf.keras.models.load_model(POLICY_SAVE_PATH)
print("Loaded policy_net:", POLICY_SAVE_PATH)
print("Policy output shape:", policy_net_loaded.output_shape)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Loaded policy_net: best_policy_net.keras
# Policy output shape: (None, 9)

# %%
# ------------------------------------------------
# Policy effect check on test samples
# (normalized + real scale)  -- Policy 39D, Xp is 40 (last = qprev)
# ------------------------------------------------
def evaluate_policy_effect_with_real_scale_39policy(
    policy_net,
    quality_model,
    dataset,
    scaler_y,
    DELTA_MAX_TF,
    n_skip_batches=1,
    n_batches=1
):
    err_before_norm = []
    err_after_norm  = []

    err_before_real = []
    err_after_real  = []

    for Xp_batch, y_target_norm in dataset.skip(n_skip_batches).take(n_batches):

        # -------------------------
        # Parse Xp_batch (B,40)
        # layout: [mon(28), qcur(1), u_cur(9), yT(1), qprev(1)]
        # -------------------------
        mon   = Xp_batch[:, 0:28]
        qcur  = Xp_batch[:, 28:29]     # policy input only (not for quality)
        u_cur = Xp_batch[:, 29:38]
        yT    = Xp_batch[:, 38:39]     # policy input only
        qprev = Xp_batch[:, 39:40]     # quality input prev quality

        # -------------------------
        # BEFORE policy (current control)
        # quality input: [u_cur, mon, qprev]  -> (B,38)
        # -------------------------
        Xq_cur = tf.concat([u_cur, mon, qprev], axis=1)
        y_pred_cur_norm = quality_model(Xq_cur, training=False)  # (B,1)

        # -------------------------
        # AFTER policy
        # policy input: first 39 dims only
        # Xp_no_prev = [mon, qcur, u_cur, yT]
        # -------------------------
        Xp_no_prev = Xp_batch[:, 0:39]  # (B,39)
        delta_raw = policy_net(Xp_no_prev, training=False)  # (B,9) in [-1,1]
        delta = delta_raw * DELTA_MAX_TF                    # bounded in normalized space
        u_new = tf.clip_by_value(u_cur + delta, 0.0, 1.0)   # (B,9)

        Xq_new = tf.concat([u_new, mon, qprev], axis=1)     # (B,38)
        y_pred_new_norm = quality_model(Xq_new, training=False)  # (B,1)

        # -------------------------
        # Normalized errors (0~1)
        # -------------------------
        err_b_norm = tf.abs(y_pred_cur_norm - y_target_norm)
        err_a_norm = tf.abs(y_pred_new_norm - y_target_norm)

        err_before_norm.append(err_b_norm.numpy())
        err_after_norm.append(err_a_norm.numpy())

        # -------------------------
        # Real-scale (Residue) errors
        # -------------------------
        y_target_real   = scaler_y.inverse_transform(y_target_norm.numpy())
        y_pred_cur_real = scaler_y.inverse_transform(y_pred_cur_norm.numpy())
        y_pred_new_real = scaler_y.inverse_transform(y_pred_new_norm.numpy())

        err_b_real = np.abs(y_pred_cur_real - y_target_real)
        err_a_real = np.abs(y_pred_new_real - y_target_real)

        err_before_real.append(err_b_real)
        err_after_real.append(err_a_real)

    # batch들 누적 후 평균
    err_b_n = float(np.mean(np.concatenate(err_before_norm, axis=0)))
    err_a_n = float(np.mean(np.concatenate(err_after_norm, axis=0)))
    err_b_r = float(np.mean(np.concatenate(err_before_real, axis=0)))
    err_a_r = float(np.mean(np.concatenate(err_after_real, axis=0)))

    return err_b_n, err_a_n, err_b_r, err_a_r


# 실행 예시
err_b_n, err_a_n, err_b_r, err_a_r = evaluate_policy_effect_with_real_scale_39policy(
    policy_net=policy_net,          # 또는 policy_net_loaded
    quality_model=quality_model,
    dataset=test_ds,
    scaler_y=scaler_y,
    DELTA_MAX_TF=DELTA_MAX_TF,
    n_skip_batches=3,
    n_batches=4
)

print("=== Policy Effect Evaluation (Policy 39D) ===")
print(f"[Normalized]")
print(f"  Mean |error| BEFORE policy : {err_b_n:.6f}")
print(f"  Mean |error| AFTER  policy : {err_a_n:.6f}")
if err_b_n > 1e-12:
    print(f"  Improvement ratio          : {(1 - err_a_n/err_b_n)*100:.2f}%")
else:
    print("  Improvement ratio          : N/A (baseline too small)")

print()
print(f"[Real Residue scale]")
print(f"  Mean |error| BEFORE policy : {err_b_r:.2f} Residue")
print(f"  Mean |error| AFTER  policy : {err_a_r:.2f} Residue")
print(f"  Improvement                : {(err_b_r - err_a_r):.2f} Residue")
# Out:
# === Policy Effect Evaluation (Policy 39D) ===
# [Normalized]
#   Mean |error| BEFORE policy : 0.077141
#   Mean |error| AFTER  policy : 0.072464
#   Improvement ratio          : 6.06%
#
# [Real Residue scale]
#   Mean |error| BEFORE policy : 0.59 Residue
#   Mean |error| AFTER  policy : 0.55 Residue
#   Improvement                : 0.04 Residue
