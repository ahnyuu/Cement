# %%
import sys
import tensorflow as tf

print(f"TensorFlow ver is {tf.__version__}")
print(f"PYTHON ver is {sys.version}")
print("GPU is","available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TensorFlow ver is 2.10.0
# PYTHON ver is 3.9.13 (tags/v3.9.13:6de2ca5, May 17 2022, 16:36:42) [MSC v.1929 64 bit (AMD64)]
# GPU is available

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import joblib
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# ============================================================
# 0) Config
# ============================================================
DATA_DIR = "database"
DATA_FILE = "cmall_remove_duplicate_m_all.csv"   # RAW(정규화 전) csv

QUALITY_MODEL_PATH = "best_model_residue.h5"      # pretrained quality ANN (frozen)
POLICY_SAVE_PATH   = "best_policy_net.keras"     # save trained policy net (Keras v3)

SCALER_X_PATH = "scaler_x_38.pkl"                # for quality inputs (38)
SCALER_Y_PATH = "scaler_y_1.pkl"                 # for residue (real unit)

RANDOM_STATE = 42
BATCH_SIZE = 1024
EPOCHS = 500

TARGET_RESIDUE_DEFAULT = 8.0

# Δu bound in normalized space (변수별로 튜닝 권장)
DELTA_MAX_DEFAULT = 0.02

# Loss weights (규제항)
LAM_L2 = 0.0
LAM_L1 = 0.0
HUBER_DELTA = 1.0

LR = 5e-4
PATIENCE = 50

# %%
# ============================================================
# 1) Column definitions
# ============================================================

CONTROL_COLS_9 = [
    "RP_roller_p1",
    "RP_roller_p2",
    "RP_sep_rpm",
    "RP_sep_fan_damper",
    "RP_sep_BF_damper",
    "mill_BF_damper",
    "mill_sep_rpm",
    "mill_sep_fan_damper",
    "grind_aid",
]
assert len(CONTROL_COLS_9) == 9

MONITOR_COLS_28 = [
    # existing monitoring (23)
    "RP_spac",
    "RP_skew",
    "RP_roller_energy1",
    "RP_roller_energy2",
    "RP_roller_vib",
    "RP_BE_energy1",
    "RP_BE_energy2",
    "RP_sep_BF_pressure",
    "dosing_BE_energy",
    "mill_feed_c",
    "mill_feed_cir",
    "mill_energy",
    "mill_in_temp",
    "mill_out_temp",
    "mill_BE_energy",
    "mill_out_gas_temp",
    "mill_out_mater_temp",
    "mill_BF_pressure",
    "mill_sep_BF_pressure",
    "mill_sep_BF_fan_damper",
    "final_BE_1",
    "final_BE_2",
    "final_mater_temp",
    # feed composition moved to monitoring (4)
    "feed_clinker",
    "feed_gypsum",
    "feed_slag",
    "feed_FA",
    # total feed moved to monitoring (1)
    "feed_total",
]
assert len(MONITOR_COLS_28) == 28

# ---- Quality vs Policy 품질 컬럼 분리
QUALITY_PREV_COL   = "residue"        # quality ANN input
POLICY_CUR_COL     = "residue"        # policy ANN input (current quality)
TARGET_QUALITY_COL = "residue_target" # policy ANN input & training target (real unit)

# ---- Quality model input (MUST match pretrained quality model training)
QUALITY_INPUT_COLS = CONTROL_COLS_9 + MONITOR_COLS_28 + [QUALITY_PREV_COL]
assert len(QUALITY_INPUT_COLS) == 38

# ---- Policy input (NOW 39): monitor 28 + current_quality 1 + current_control 9 + target 1
POLICY_INPUT_DIM = 28 + 1 + 9 + 1
assert POLICY_INPUT_DIM == 39

print("QUALITY_INPUT_DIM:", len(QUALITY_INPUT_COLS))
print("POLICY_INPUT_DIM :", POLICY_INPUT_DIM)
# Out:
# QUALITY_INPUT_DIM: 38
# POLICY_INPUT_DIM : 39

# %%
# ============================================================
# 2) Load raw data
# ============================================================
csv_path = os.path.join(DATA_DIR, DATA_FILE)
df = pd.read_csv(csv_path)

# Ensure target column
if TARGET_QUALITY_COL not in df.columns:
    df[TARGET_QUALITY_COL] = TARGET_RESIDUE_DEFAULT

required_cols = list(set(
    QUALITY_INPUT_COLS +          # includes residue_prev
    [POLICY_CUR_COL] +            # includes residue
    [TARGET_QUALITY_COL]          # includes residue_target
))

missing_cols = [c for c in required_cols if c not in df.columns]
if missing_cols:
    raise ValueError(f"Missing columns in CSV: {missing_cols}")

df = df.dropna(subset=required_cols).reset_index(drop=True)
print(f"Loaded raw data: {df.shape} from {csv_path}")
print("Target unique count:", df[TARGET_QUALITY_COL].nunique())
# Out:
# Loaded raw data: (60572, 43) from database\cmall_remove_duplicate_m_all.csv
# Target unique count: 1

# %%
# ============================================================
# 3) Split indices
# ============================================================
idx_all = np.arange(len(df))
idx_train, idx_temp = train_test_split(idx_all, test_size=0.30, random_state=RANDOM_STATE)
idx_val, idx_test   = train_test_split(idx_temp, test_size=0.50, random_state=RANDOM_STATE)

print(f"Split: train={len(idx_train)}, val={len(idx_val)}, test={len(idx_test)}")
# Out:
# Split: train=42400, val=9086, test=9086

# %%
# ============================================================
# 4) Fit scalers (train only) & save
# ============================================================

# scaler_x: quality input 38개 (controls+monitor+residue_prev) ==================================================
scaler_x = MinMaxScaler(feature_range=(0.0, 1.0))
scaler_x.fit(df.loc[idx_all, QUALITY_INPUT_COLS].to_numpy(dtype=np.float32))

# 2) residue / residue_prev 컬럼 인덱스 찾기
residue_idx = QUALITY_INPUT_COLS.index("residue")

# 3) 강제 min/max 지정
CUSTOM_MIN = 3.4
CUSTOM_MAX = 11.5

for idx in [residue_idx]:     #for idx in [residue_idx, residue_prev_idx]:
    scaler_x.data_min_[idx] = CUSTOM_MIN
    scaler_x.data_max_[idx] = CUSTOM_MAX
    scaler_x.data_range_[idx] = CUSTOM_MAX - CUSTOM_MIN
    scaler_x.scale_[idx] = 1.0 / (CUSTOM_MAX - CUSTOM_MIN)
    scaler_x.min_[idx] = -CUSTOM_MIN / (CUSTOM_MAX - CUSTOM_MIN)

print("Custom scaling applied to residue columns")

# scaler_y: residue real unit (policy current/target, and inverse for printing) ================================
scaler_y = MinMaxScaler(feature_range=(0.0, 1.0))
scaler_y.fit(df.loc[idx_all, [POLICY_CUR_COL]].to_numpy(dtype=np.float32))

# 2) residue / residue_prev 컬럼 인덱스 찾기
residue_idx = POLICY_CUR_COL.index("residue")

# 3) 강제 min/max 지정
CUSTOM_MIN = 3.4
CUSTOM_MAX = 11.5

for idx in [residue_idx]:     #for idx in [residue_idx, residue_prev_idx]:
    scaler_y.data_min_[idx] = CUSTOM_MIN
    scaler_y.data_max_[idx] = CUSTOM_MAX
    scaler_y.data_range_[idx] = CUSTOM_MAX - CUSTOM_MIN
    scaler_y.scale_[idx] = 1.0 / (CUSTOM_MAX - CUSTOM_MIN)
    scaler_y.min_[idx] = -CUSTOM_MIN / (CUSTOM_MAX - CUSTOM_MIN)

print("Custom scaling applied to residue columns")

joblib.dump(scaler_x, SCALER_X_PATH)
joblib.dump(scaler_y, SCALER_Y_PATH)

print("Saved scalers:", SCALER_X_PATH, SCALER_Y_PATH)
# Out:
# Custom scaling applied to residue columns
# Custom scaling applied to residue columns
# Saved scalers: scaler_x_38.pkl scaler_y_1.pkl

# %%
# ============================================================
# 5) Load pretrained quality model (FROZEN)
# ============================================================
quality_model = tf.keras.models.load_model(QUALITY_MODEL_PATH)
quality_model.trainable = False

print("Quality model input/output:", quality_model.input_shape, quality_model.output_shape)
# Out:
# Quality model input/output: (None, 38) (None, 1)

# %%
# ============================================================
# 6) Build normalized arrays for policy training (39(+1)-D)
# ============================================================

# ---- raw arrays
u_cur_raw  = df[CONTROL_COLS_9].to_numpy(dtype=np.float32)            # (N,9)
mon_raw    = df[MONITOR_COLS_28].to_numpy(dtype=np.float32)           # (N,28)
qprev_raw  = df[[QUALITY_PREV_COL]].to_numpy(dtype=np.float32)        # (N,1)  quality prev
qcur_raw   = df[[POLICY_CUR_COL]].to_numpy(dtype=np.float32)          # (N,1)  policy current
yT_raw     = df[[TARGET_QUALITY_COL]].to_numpy(dtype=np.float32)      # (N,1)  policy target

# ---- quality input raw (38): [u_cur, mon, qprev]
Xq_raw = np.concatenate([u_cur_raw, mon_raw, qprev_raw], axis=1)      # (N,38)

# ---- normalize quality input via scaler_x (0~1)
Xq_norm = scaler_x.transform(Xq_raw).astype(np.float32)               # (N,38)
u_cur_norm = Xq_norm[:, :9]                                           # (N,9)
mon_norm   = Xq_norm[:, 9:9+28]                                       # (N,28)
qprev_norm = Xq_norm[:, 9+28:9+28+1]                                  # (N,1) normalized residue_prev space

# ---- normalize policy current & target via scaler_y (0~1)
qcur_norm = scaler_y.transform(qcur_raw).astype(np.float32)           # (N,1)
yT_norm   = scaler_y.transform(yT_raw).astype(np.float32)             # (N,1)

# ---- policy input (39(+1)):
# [mon_norm(28), qcur_norm(1), u_cur_norm(9), yT_norm(1), qprev_norm(1)]
Xp = np.concatenate([mon_norm, qcur_norm, u_cur_norm, yT_norm, qprev_norm], axis=1).astype(np.float32)
assert Xp.shape[1] == POLICY_INPUT_DIM + 1

# ---- split
Xp_train, yT_train = Xp[idx_train], yT_norm[idx_train]
Xp_val,   yT_val   = Xp[idx_val],   yT_norm[idx_val]
Xp_test,  yT_test  = Xp[idx_test],  yT_norm[idx_test]

print("Policy arrays:",
      "train", Xp_train.shape, yT_train.shape,
      "| val", Xp_val.shape, yT_val.shape,
      "| test", Xp_test.shape, yT_test.shape)
# Out:
# Policy arrays: train (42400, 40) (42400, 1) | val (9086, 40) (9086, 1) | test (9086, 40) (9086, 1)

# %%
# ============================================================
# 7) tf.data datasets
# ============================================================
train_ds = tf.data.Dataset.from_tensor_slices((Xp_train, yT_train)) \
    .shuffle(20000, seed=RANDOM_STATE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((Xp_val, yT_val)) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((Xp_test, yT_test)) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

print("Datasets ready.")
# Out:
# Datasets ready.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout

# ============================================================
# 8) Build policy network (delta-u for 9 controls)
# ============================================================
def build_policy_model(input_shape):
    model = Sequential([
        Dense(128, activation='swish',
              kernel_initializer='glorot_uniform',
              input_shape=input_shape),
        BatchNormalization(),
        Dropout(0.1),

        Dense(1024, activation='swish',
              kernel_initializer='glorot_uniform'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(2048, activation='swish',
              kernel_initializer='glorot_uniform'),
        BatchNormalization(),
        Dropout(0.3),

        Dense(2048, activation='swish',
              kernel_initializer='glorot_uniform'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(1024, activation='swish',
              kernel_initializer='glorot_uniform'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(64, activation='swish',
              kernel_initializer='glorot_uniform'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(9, activation='tanh', name='delta_raw')  # in [-1, 1]
    ])
    return model

policy_net = build_policy_model((POLICY_INPUT_DIM,))
policy_net.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               5120
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1024)              132096
#
#  batch_normalization_1 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 2048)              2099200
#
#  batch_normalization_2 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 2048)              4196352
#
#  batch_normalization_3 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 1024)              2098176
#
#  batch_normalization_4 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 64)                65600
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  delta_raw (Dense)           (None, 9)                 585
#
# =================================================================
# Total params: 8,622,473
# Trainable params: 8,609,801
# Non-trainable params: 12,672
# _________________________________________________________________

# %%
# ============================================================
# 9) Delta bounds (per-control) in normalized space
# ============================================================

DELTA_MAX = np.array([DELTA_MAX_DEFAULT] * 9, dtype=np.float32)  # (9,)
DELTA_MAX_TF = tf.constant(DELTA_MAX.reshape(1, -1), dtype=tf.float32)

print("DELTA_MAX:", DELTA_MAX)
# Out:
# DELTA_MAX: [0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]

# %%
# ============================================================
# 10) Wrapper model: frozen quality model + trainable policy model
#     Xp layout (40):
#       [mon(28), qcur(1), u_cur(9), y_target(1), qprev(1)]
#     quality input (38):
#       [u_new(9), mon(28), qprev(1)]
# ============================================================
class ControlRecommender(tf.keras.Model):
    def __init__(self, policy_net: tf.keras.Model, quality_model: tf.keras.Model,
                 lam_l2: float = 1.0, lam_l1: float = 0.1, huber_delta: float = 1.0):
        super().__init__()
        self.policy_net = policy_net
        self.quality_model = quality_model  # frozen

        self.lam_l2 = lam_l2
        self.lam_l1 = lam_l1
        self.huber_delta = huber_delta

        self.loss_tracker = tf.keras.metrics.Mean(name="loss")
        self.pred_loss_tracker = tf.keras.metrics.Mean(name="pred_loss")
        self.delta_l2_tracker = tf.keras.metrics.Mean(name="delta_l2")
        self.delta_l1_tracker = tf.keras.metrics.Mean(name="delta_l1")

    @property
    def metrics(self):
        return [self.loss_tracker, self.pred_loss_tracker,
                self.delta_l2_tracker, self.delta_l1_tracker]

    def call(self, Xp_batch, training=False):
        # Xp layout
        mon   = Xp_batch[:, 0:28]
        qcur  = Xp_batch[:, 28:29]    # policy input only (not used in quality input)
        u_cur = Xp_batch[:, 29:38]
        yT    = Xp_batch[:, 38:39]    # policy input only (loss uses yT separately)
        qprev = Xp_batch[:, 39:40]    # IMPORTANT: quality input prev quality

        # policy input: qprev 제외한 39차원만 사용
        Xp_no_prev = Xp_batch[:, 0:39]  # = [mon(28), qcur(1), u_cur(9), yT(1)]

        # policy_net outputs delta_raw in [-1,1]
        delta_raw = self.policy_net(Xp_no_prev, training=training)  # (B,9)
        delta = delta_raw * DELTA_MAX_TF                          # bounded
        u_new = tf.clip_by_value(u_cur + delta, 0.0, 1.0)         # (B,9)

        # quality input (38): [u_new(9), mon(28), qprev(1)]
        Xq_new = tf.concat([u_new, mon, qprev], axis=1)           # (B,38)
        y_pred = self.quality_model(Xq_new, training=False)       # (B,1)

        return u_new, y_pred, delta

    def train_step(self, data):
        Xp_batch, y_target_batch = data

        with tf.GradientTape() as tape:
            _, y_pred, delta = self(Xp_batch, training=True)

            pred_loss = tf.reduce_mean(
                tf.keras.losses.huber(y_target_batch, y_pred, delta=self.huber_delta)
            )

            delta_l2 = tf.reduce_mean(tf.reduce_sum(tf.square(delta), axis=1))
            delta_l1 = tf.reduce_mean(tf.reduce_sum(tf.abs(delta), axis=1))

            loss = pred_loss + self.lam_l2 * delta_l2 + self.lam_l1 * delta_l1

        grads = tape.gradient(loss, self.policy_net.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.policy_net.trainable_variables))

        self.loss_tracker.update_state(loss)
        self.pred_loss_tracker.update_state(pred_loss)
        self.delta_l2_tracker.update_state(delta_l2)
        self.delta_l1_tracker.update_state(delta_l1)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        Xp_batch, y_target_batch = data

        _, y_pred, delta = self(Xp_batch, training=False)

        pred_loss = tf.reduce_mean(
            tf.keras.losses.huber(y_target_batch, y_pred, delta=self.huber_delta)
        )
        delta_l2 = tf.reduce_mean(tf.reduce_sum(tf.square(delta), axis=1))
        delta_l1 = tf.reduce_mean(tf.reduce_sum(tf.abs(delta), axis=1))

        loss = pred_loss + self.lam_l2 * delta_l2 + self.lam_l1 * delta_l1

        self.loss_tracker.update_state(loss)
        self.pred_loss_tracker.update_state(pred_loss)
        self.delta_l2_tracker.update_state(delta_l2)
        self.delta_l1_tracker.update_state(delta_l1)

        return {m.name: m.result() for m in self.metrics}

# %%
# ============================================================
# 11) Train policy (recommender)
# ============================================================
quality_model.trainable = False

recommender = ControlRecommender(
    policy_net=policy_net,
    quality_model=quality_model,
    lam_l2=LAM_L2,
    lam_l1=LAM_L1,
    huber_delta=HUBER_DELTA
)

recommender.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LR))

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=PATIENCE, restore_best_weights=True
)

history = recommender.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[early_stop],
    verbose=1
)

print("\nEvaluation on test set:")
recommender.evaluate(test_ds, verbose=1)

# ---- Save ONLY policy_net (권장)
policy_net.save(POLICY_SAVE_PATH)
print("Saved policy_net to:", POLICY_SAVE_PATH)
# Out:
# Epoch 1/500
# 42/42 [==============================] - 6s 55ms/step - loss: 0.0061 - pred_loss: 0.0061 - delta_l2: 0.0023 - delta_l1: 0.1323 - val_loss: 0.0084 - val_pred_loss: 0.0084 - val_delta_l2: 6.4726e-04 - val_delta_l1: 0.0665
# Epoch 2/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0059 - pred_loss: 0.0059 - delta_l2: 0.0026 - delta_l1: 0.1442 - val_loss: 0.0084 - val_pred_loss: 0.0084 - val_delta_l2: 8.5579e-04 - val_delta_l1: 0.0736
# Epoch 3/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0058 - pred_loss: 0.0058 - delta_l2: 0.0027 - delta_l1: 0.1493 - val_loss: 0.0083 - val_pred_loss: 0.0083 - val_delta_l2: 0.0011 - val_delta_l1: 0.0870
# Epoch 4/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0058 - pred_loss: 0.0058 - delta_l2: 0.0028 - delta_l1: 0.1514 - val_loss: 0.0082 - val_pred_loss: 0.0082 - val_delta_l2: 0.0015 - val_delta_l1: 0.1051
# Epoch 5/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0058 - pred_loss: 0.0058 - delta_l2: 0.0028 - delta_l1: 0.1533 - val_loss: 0.0078 - val_pred_loss: 0.0078 - val_delta_l2: 0.0018 - val_delta_l1: 0.1159
# Epoch 6/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0058 - pred_loss: 0.0058 - delta_l2: 0.0029 - delta_l1: 0.1545 - val_loss: 0.0074 - val_pred_loss: 0.0074 - val_delta_l2: 0.0020 - val_delta_l1: 0.1207
# Epoch 7/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0057 - pred_loss: 0.0057 - delta_l2: 0.0029 - delta_l1: 0.1555 - val_loss: 0.0068 - val_pred_loss: 0.0068 - val_delta_l2: 0.0022 - val_delta_l1: 0.1320
# Epoch 8/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0057 - pred_loss: 0.0057 - delta_l2: 0.0029 - delta_l1: 0.1562 - val_loss: 0.0065 - val_pred_loss: 0.0065 - val_delta_l2: 0.0024 - val_delta_l1: 0.1384
# Epoch 9/500
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0057 - pred_loss: 0.0057 - delta_l2: 0.0029 - delta_l1: 0.1574 - val_loss: 0.0063 - val_pred_loss: 0.0063 - val_delta_l2: 0.0020 - val_delta_l1: 0.1246
# Epoch 10/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0057 - pred_loss: 0.0057 - delta_l2: 0.0030 - delta_l1: 0.1579 - val_loss: 0.0061 - val_pred_loss: 0.0061 - val_delta_l2: 0.0023 - val_delta_l1: 0.1331
# Epoch 11/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0057 - pred_loss: 0.0057 - delta_l2: 0.0030 - delta_l1: 0.1587 - val_loss: 0.0061 - val_pred_loss: 0.0061 - val_delta_l2: 0.0024 - val_delta_l1: 0.1382
# Epoch 12/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0057 - pred_loss: 0.0057 - delta_l2: 0.0030 - delta_l1: 0.1591 - val_loss: 0.0060 - val_pred_loss: 0.0060 - val_delta_l2: 0.0025 - val_delta_l1: 0.1408
# Epoch 13/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0057 - pred_loss: 0.0057 - delta_l2: 0.0030 - delta_l1: 0.1594 - val_loss: 0.0058 - val_pred_loss: 0.0058 - val_delta_l2: 0.0027 - val_delta_l1: 0.1473
# Epoch 14/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0057 - pred_loss: 0.0057 - delta_l2: 0.0030 - delta_l1: 0.1599 - val_loss: 0.0058 - val_pred_loss: 0.0058 - val_delta_l2: 0.0027 - val_delta_l1: 0.1497
# Epoch 15/500
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0056 - pred_loss: 0.0056 - delta_l2: 0.0030 - delta_l1: 0.1601 - val_loss: 0.0057 - val_pred_loss: 0.0057 - val_delta_l2: 0.0028 - val_delta_l1: 0.1520
# Epoch 16/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0057 - pred_loss: 0.0057 - delta_l2: 0.0030 - delta_l1: 0.1606 - val_loss: 0.0056 - val_pred_loss: 0.0056 - val_delta_l2: 0.0028 - val_delta_l1: 0.1538
# Epoch 17/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0056 - pred_loss: 0.0056 - delta_l2: 0.0030 - delta_l1: 0.1608 - val_loss: 0.0056 - val_pred_loss: 0.0056 - val_delta_l2: 0.0029 - val_delta_l1: 0.1574
# Epoch 18/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0056 - pred_loss: 0.0056 - delta_l2: 0.0030 - delta_l1: 0.1610 - val_loss: 0.0056 - val_pred_loss: 0.0056 - val_delta_l2: 0.0030 - val_delta_l1: 0.1575
# Epoch 19/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0056 - pred_loss: 0.0056 - delta_l2: 0.0031 - delta_l1: 0.1618 - val_loss: 0.0056 - val_pred_loss: 0.0056 - val_delta_l2: 0.0029 - val_delta_l1: 0.1568
# Epoch 20/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0056 - pred_loss: 0.0056 - delta_l2: 0.0031 - delta_l1: 0.1613 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0030 - val_delta_l1: 0.1594
# Epoch 21/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0056 - pred_loss: 0.0056 - delta_l2: 0.0031 - delta_l1: 0.1619 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0030 - val_delta_l1: 0.1591
# Epoch 22/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0056 - pred_loss: 0.0056 - delta_l2: 0.0031 - delta_l1: 0.1617 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0030 - val_delta_l1: 0.1592
# Epoch 23/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0056 - pred_loss: 0.0056 - delta_l2: 0.0031 - delta_l1: 0.1618 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0031 - val_delta_l1: 0.1610
# Epoch 24/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0056 - pred_loss: 0.0056 - delta_l2: 0.0031 - delta_l1: 0.1622 - val_loss: 0.0056 - val_pred_loss: 0.0056 - val_delta_l2: 0.0030 - val_delta_l1: 0.1593
# Epoch 25/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1625 - val_loss: 0.0056 - val_pred_loss: 0.0056 - val_delta_l2: 0.0030 - val_delta_l1: 0.1583
# Epoch 26/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0056 - pred_loss: 0.0056 - delta_l2: 0.0031 - delta_l1: 0.1623 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0031 - val_delta_l1: 0.1613
# Epoch 27/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1627 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0031 - val_delta_l1: 0.1617
# Epoch 28/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1633 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0031 - val_delta_l1: 0.1624
# Epoch 29/500
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1633 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0031 - val_delta_l1: 0.1611
# Epoch 30/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1633 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0031 - val_delta_l1: 0.1611
# Epoch 31/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1635 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1632
# Epoch 32/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1635 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1611
# Epoch 33/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1639 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1621
# Epoch 34/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1638 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1616
# Epoch 35/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1640 - val_loss: 0.0056 - val_pred_loss: 0.0056 - val_delta_l2: 0.0030 - val_delta_l1: 0.1608
# Epoch 36/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1644 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0031 - val_delta_l1: 0.1621
# Epoch 37/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1640 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1624
# Epoch 38/500
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1641 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1632
# Epoch 39/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0031 - delta_l1: 0.1644 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1655
# Epoch 40/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0032 - delta_l1: 0.1646 - val_loss: 0.0056 - val_pred_loss: 0.0056 - val_delta_l2: 0.0030 - val_delta_l1: 0.1599
# Epoch 41/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0032 - delta_l1: 0.1647 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1624
# Epoch 42/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1649 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0031 - val_delta_l1: 0.1630
# Epoch 43/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1648 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1635
# Epoch 44/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1651 - val_loss: 0.0055 - val_pred_loss: 0.0055 - val_delta_l2: 0.0031 - val_delta_l1: 0.1622
# Epoch 45/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1651 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1640
# Epoch 46/500
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0055 - pred_loss: 0.0055 - delta_l2: 0.0032 - delta_l1: 0.1653 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1674
# Epoch 47/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1651 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0031 - val_delta_l1: 0.1633
# Epoch 48/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1652 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0031 - val_delta_l1: 0.1642
# Epoch 49/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1652 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1652
# Epoch 50/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1654 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1662
# Epoch 51/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1655 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0031 - val_delta_l1: 0.1643
# Epoch 52/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1656 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1670
# Epoch 53/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1658 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0031 - val_delta_l1: 0.1643
# Epoch 54/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1658 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1654
# Epoch 55/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1660 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1671
# Epoch 56/500
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1659 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1658
# Epoch 57/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1660 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1636
# Epoch 58/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1660 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1635
# Epoch 59/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1660 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1671
# Epoch 60/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1662 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1665
# Epoch 61/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1663 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1631
# Epoch 62/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1662 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1654
# Epoch 63/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1664 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1674
# Epoch 64/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1665 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1653
# Epoch 65/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1667 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1666
# Epoch 66/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1668 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1658
# Epoch 67/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1665 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1671
# Epoch 68/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1668 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1665
# Epoch 69/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0054 - pred_loss: 0.0054 - delta_l2: 0.0032 - delta_l1: 0.1669 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1654
# Epoch 70/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1671 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0033 - val_delta_l1: 0.1697
# Epoch 71/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1672 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0033 - val_delta_l1: 0.1696
# Epoch 72/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1672 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1675
# Epoch 73/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1672 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1668
# Epoch 74/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1673 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1673
# Epoch 75/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1674 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0031 - val_delta_l1: 0.1639
# Epoch 76/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1674 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1666
# Epoch 77/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1675 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1666
# Epoch 78/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1675 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1678
# Epoch 79/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1674 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1661
# Epoch 80/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1676 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1656
# Epoch 81/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1676 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1660
# Epoch 82/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1676 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1662
# Epoch 83/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1677 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1684
# Epoch 84/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1677 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1671
# Epoch 85/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1677 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1690
# Epoch 86/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1679 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1677
# Epoch 87/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1679 - val_loss: 0.0053 - val_pred_loss: 0.0053 - val_delta_l2: 0.0032 - val_delta_l1: 0.1652
# Epoch 88/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0032 - delta_l1: 0.1678 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1675
# Epoch 89/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1680 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1675
# Epoch 90/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1681 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1678
# Epoch 91/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1680 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1682
# Epoch 92/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1683 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1667
# Epoch 93/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1683 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1674
# Epoch 94/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1681 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1674
# Epoch 95/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1682 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1689
# Epoch 96/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1681 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1691
# Epoch 97/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1682 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 98/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1683 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1694
# Epoch 99/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1684 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1695
# Epoch 100/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1683 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1691
# Epoch 101/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1683 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1683
# Epoch 102/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1682 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1686
# Epoch 103/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1686 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1682
# Epoch 104/500
# 42/42 [==============================] - 2s 40ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1682 - val_loss: 0.0054 - val_pred_loss: 0.0054 - val_delta_l2: 0.0032 - val_delta_l1: 0.1657
# Epoch 105/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1686 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1700
# Epoch 106/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1686 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1687
# Epoch 107/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1687 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1684
# Epoch 108/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1685 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1697
# Epoch 109/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1683 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1684
# Epoch 110/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1686 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1676
# Epoch 111/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1685 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1682
# Epoch 112/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1687 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1669
# Epoch 113/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1685 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1679
# Epoch 114/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1686 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1667
# Epoch 115/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0053 - pred_loss: 0.0053 - delta_l2: 0.0033 - delta_l1: 0.1687 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1698
# Epoch 116/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1688 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1677
# Epoch 117/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1687 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1690
# Epoch 118/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1687 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1685
# Epoch 119/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1687 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1694
# Epoch 120/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1688 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1698
# Epoch 121/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1689 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1692
# Epoch 122/500
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1689 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1693
# Epoch 123/500
# 42/42 [==============================] - 2s 38ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1689 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1693
# Epoch 124/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1690 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1681
# Epoch 125/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1690 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1689
# Epoch 126/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1690 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
# Epoch 127/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1690 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1692
# Epoch 128/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1691 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1696
# Epoch 129/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1690 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0034 - val_delta_l1: 0.1714
# Epoch 130/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1692 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1681
# Epoch 131/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1690 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1705
# Epoch 132/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1692 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1689
# Epoch 133/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1693 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1680
# Epoch 134/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1693 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1698
# Epoch 135/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1694 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1704
# Epoch 136/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1692 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1689
# Epoch 137/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1693 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1688
# Epoch 138/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1693 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1689
# Epoch 139/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1694 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1708
# Epoch 140/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1695 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1695
# Epoch 141/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1695 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1693
# Epoch 142/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1695 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1710
# Epoch 143/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1695 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
# Epoch 144/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1695 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1706
# Epoch 145/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1695 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1696
# Epoch 146/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1693 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1694
# Epoch 147/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1694 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1684
# Epoch 148/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1696 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1706
# Epoch 149/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1694 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1692
# Epoch 150/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1695 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1706
# Epoch 151/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1696 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1701
# Epoch 152/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1697 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 153/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1697 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1705
# Epoch 154/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1697 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1710
# Epoch 155/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1696 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 156/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1697 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1711
# Epoch 157/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1696 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 158/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1696 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1701
# Epoch 159/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1698 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1705
# Epoch 160/500
# 42/42 [==============================] - 1s 33ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1698 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1695
# Epoch 161/500
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1698 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1699
# Epoch 162/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1697 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1697
# Epoch 163/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1698
# Epoch 164/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
# Epoch 165/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1700 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1696
# Epoch 166/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1698 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1714
# Epoch 167/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0052 - pred_loss: 0.0052 - delta_l2: 0.0033 - delta_l1: 0.1700 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 168/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
# Epoch 169/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1700 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1707
# Epoch 170/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1706
# Epoch 171/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1702
# Epoch 172/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1700 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1699
# Epoch 173/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1698 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 174/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1698 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1711
# Epoch 175/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1698 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1704
# Epoch 176/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1700 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1701
# Epoch 177/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1708
# Epoch 178/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1704
# Epoch 179/500
# 42/42 [==============================] - 2s 39ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1698 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1708
# Epoch 180/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1692
# Epoch 181/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1701
# Epoch 182/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1700 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1685
# Epoch 183/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1701 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1688
# Epoch 184/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1700 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1705
# Epoch 185/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1702
# Epoch 186/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1699 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0034 - val_delta_l1: 0.1714
# Epoch 187/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1701 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1710
# Epoch 188/500
# 42/42 [==============================] - 2s 44ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1700 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1704
# Epoch 189/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1701 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1711
# Epoch 190/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1700 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1704
# Epoch 191/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1700 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1700
# Epoch 192/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1701 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0034 - val_delta_l1: 0.1715
# Epoch 193/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1701 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1707
# Epoch 194/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1701 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 195/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1704 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
# Epoch 196/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 197/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1701 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
# Epoch 198/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1705
# Epoch 199/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1700
# Epoch 200/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1695
# Epoch 201/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 202/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1701
# Epoch 203/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1699
# Epoch 204/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1702 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1702
# Epoch 205/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1702 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1702
# Epoch 206/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1708
# Epoch 207/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0034 - val_delta_l1: 0.1714
# Epoch 208/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1706
# Epoch 209/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0051 - pred_loss: 0.0051 - delta_l2: 0.0033 - delta_l1: 0.1703 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1707
# Epoch 210/500
# ...
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1708 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0034 - val_delta_l1: 0.1718
# Epoch 281/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0034 - val_delta_l1: 0.1714
# Epoch 282/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 283/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1704
# Epoch 284/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0064 - val_pred_loss: 0.0064 - val_delta_l2: 0.0032 - val_delta_l1: 0.1671
# Epoch 285/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1708 - val_loss: 0.0056 - val_pred_loss: 0.0056 - val_delta_l2: 0.0032 - val_delta_l1: 0.1668
# Epoch 286/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1708 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1686
# Epoch 287/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1705
# Epoch 288/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1708
# Epoch 289/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1708
# Epoch 290/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1707
# Epoch 291/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1713
# Epoch 292/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1702
# Epoch 293/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1714
# Epoch 294/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
# Epoch 295/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
# Epoch 296/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1712
# Epoch 297/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1719
# Epoch 298/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1718
# Epoch 299/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1711 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1706
# Epoch 300/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1711 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0034 - val_delta_l1: 0.1716
# Epoch 301/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0034 - val_delta_l1: 0.1719
# Epoch 302/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1715
# Epoch 303/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1711 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1706
# Epoch 304/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0056 - val_pred_loss: 0.0056 - val_delta_l2: 0.0033 - val_delta_l1: 0.1682
# Epoch 305/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1709 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0032 - val_delta_l1: 0.1677
# Epoch 306/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1708 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1699
# Epoch 307/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1689
# Epoch 308/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1710 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1701
# Epoch 309/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1711 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1713
# Epoch 310/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1711 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1714
# Epoch 311/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1711 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1711
# Epoch 312/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1711 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1713
# Epoch 313/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1711 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1714
# Epoch 314/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0034 - val_delta_l1: 0.1715
# Epoch 315/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1716
# Epoch 316/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1723
# Epoch 317/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1716
# Epoch 318/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1723
# Epoch 319/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1714 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1718
# Epoch 320/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1714 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1708
# Epoch 321/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0034 - delta_l1: 0.1714 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1699
# Epoch 322/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1715
# Epoch 323/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
# Epoch 324/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1720
# Epoch 325/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1713
# Epoch 326/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1716
# Epoch 327/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1717
# Epoch 328/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1714 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
# Epoch 329/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1719
# Epoch 330/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1711
# Epoch 331/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1714
# Epoch 332/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 333/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0033 - val_delta_l1: 0.1703
# Epoch 334/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1714
# Epoch 335/500
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1711 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1710
# Epoch 336/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1718
# Epoch 337/500
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1721
# Epoch 338/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0034 - val_delta_l1: 0.1721
# Epoch 339/500
# 42/42 [==============================] - 1s 25ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0034 - delta_l1: 0.1714 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1704
# Epoch 340/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1712
# Epoch 341/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1714 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1695
# Epoch 342/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0050 - pred_loss: 0.0050 - delta_l2: 0.0033 - delta_l1: 0.1713 - val_loss: 0.0051 - val_pred_loss: 0.0051 - val_delta_l2: 0.0033 - val_delta_l1: 0.1710
# Epoch 343/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1710
# Epoch 344/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1714 - val_loss: 0.0049 - val_pred_loss: 0.0049 - val_delta_l2: 0.0033 - val_delta_l1: 0.1708
# Epoch 345/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0034 - delta_l1: 0.1714 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1710
# Epoch 346/500
# 42/42 [==============================] - 1s 23ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0034 - delta_l1: 0.1714 - val_loss: 0.0052 - val_pred_loss: 0.0052 - val_delta_l2: 0.0034 - val_delta_l1: 0.1718
# Epoch 347/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0049 - pred_loss: 0.0049 - delta_l2: 0.0033 - delta_l1: 0.1712 - val_loss: 0.0050 - val_pred_loss: 0.0050 - val_delta_l2: 0.0033 - val_delta_l1: 0.1709
#
# Evaluation on test set:
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0048 - pred_loss: 0.0048 - delta_l2: 0.0034 - delta_l1: 0.1717
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved policy_net to: best_policy_net.keras

# %%
# ============================================================
# 12) Plot training curves
# ============================================================
hist = history.history

plt.figure(figsize=(10,5))
plt.plot(hist["loss"], label="train total loss")
plt.plot(hist["val_loss"], label="val total loss")
plt.title("Policy training - Total Loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# pred_loss도 기록되어 있으면 같이 출력
if "pred_loss" in hist:
    plt.figure(figsize=(10,5))
    plt.plot(hist["pred_loss"], label="train pred_loss")
    plt.plot(hist.get("val_pred_loss", []), label="val pred_loss")
    plt.title("Policy training - Prediction Loss (Huber)")
    plt.xlabel("epoch")
    plt.ylabel("pred_loss")
    plt.legend()
    plt.show()

# 규제항도 기록되어 있으면 출력
if "delta_l2" in hist:
    plt.figure(figsize=(10,5))
    plt.plot(hist["delta_l2"], label="train delta_l2")
    plt.plot(hist.get("val_delta_l2", []), label="val delta_l2")
    plt.title("Delta L2")
    plt.xlabel("epoch")
    plt.ylabel("delta_l2")
    plt.legend()
    plt.show()

if "delta_l1" in hist:
    plt.figure(figsize=(10,5))
    plt.plot(hist["delta_l1"], label="train delta_l1")
    plt.plot(hist.get("val_delta_l1", []), label="val delta_l1")
    plt.title("Delta L1")
    plt.xlabel("epoch")
    plt.ylabel("delta_l1")
    plt.legend()
    plt.show()

# %%
# ============================================================
# 13) Quick reload check
# ============================================================
policy_net_loaded = tf.keras.models.load_model(POLICY_SAVE_PATH)
print("Loaded policy_net:", POLICY_SAVE_PATH)
print("Policy output shape:", policy_net_loaded.output_shape)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Loaded policy_net: best_policy_net.keras
# Policy output shape: (None, 9)

# %%
# ------------------------------------------------
# Policy effect check on test samples
# (normalized + real scale)  -- Policy 39D, Xp is 40 (last = qprev)
# ------------------------------------------------
def evaluate_policy_effect_with_real_scale_39policy(
    policy_net,
    quality_model,
    dataset,
    scaler_y,
    DELTA_MAX_TF,
    n_skip_batches=1,
    n_batches=1
):
    err_before_norm = []
    err_after_norm  = []

    err_before_real = []
    err_after_real  = []

    for Xp_batch, y_target_norm in dataset.skip(n_skip_batches).take(n_batches):

        # -------------------------
        # Parse Xp_batch (B,40)
        # layout: [mon(28), qcur(1), u_cur(9), yT(1), qprev(1)]
        # -------------------------
        mon   = Xp_batch[:, 0:28]
        qcur  = Xp_batch[:, 28:29]     # policy input only (not for quality)
        u_cur = Xp_batch[:, 29:38]
        yT    = Xp_batch[:, 38:39]     # policy input only
        qprev = Xp_batch[:, 39:40]     # quality input prev quality

        # -------------------------
        # BEFORE policy (current control)
        # quality input: [u_cur, mon, qprev]  -> (B,38)
        # -------------------------
        Xq_cur = tf.concat([u_cur, mon, qprev], axis=1)
        y_pred_cur_norm = quality_model(Xq_cur, training=False)  # (B,1)

        # -------------------------
        # AFTER policy
        # policy input: first 39 dims only
        # Xp_no_prev = [mon, qcur, u_cur, yT]
        # -------------------------
        Xp_no_prev = Xp_batch[:, 0:39]  # (B,39)
        delta_raw = policy_net(Xp_no_prev, training=False)  # (B,9) in [-1,1]
        delta = delta_raw * DELTA_MAX_TF                    # bounded in normalized space
        u_new = tf.clip_by_value(u_cur + delta, 0.0, 1.0)   # (B,9)

        Xq_new = tf.concat([u_new, mon, qprev], axis=1)     # (B,38)
        y_pred_new_norm = quality_model(Xq_new, training=False)  # (B,1)

        # -------------------------
        # Normalized errors (0~1)
        # -------------------------
        err_b_norm = tf.abs(y_pred_cur_norm - y_target_norm)
        err_a_norm = tf.abs(y_pred_new_norm - y_target_norm)

        err_before_norm.append(err_b_norm.numpy())
        err_after_norm.append(err_a_norm.numpy())

        # -------------------------
        # Real-scale (Residue) errors
        # -------------------------
        y_target_real   = scaler_y.inverse_transform(y_target_norm.numpy())
        y_pred_cur_real = scaler_y.inverse_transform(y_pred_cur_norm.numpy())
        y_pred_new_real = scaler_y.inverse_transform(y_pred_new_norm.numpy())

        err_b_real = np.abs(y_pred_cur_real - y_target_real)
        err_a_real = np.abs(y_pred_new_real - y_target_real)

        err_before_real.append(err_b_real)
        err_after_real.append(err_a_real)

    # batch들 누적 후 평균
    err_b_n = float(np.mean(np.concatenate(err_before_norm, axis=0)))
    err_a_n = float(np.mean(np.concatenate(err_after_norm, axis=0)))
    err_b_r = float(np.mean(np.concatenate(err_before_real, axis=0)))
    err_a_r = float(np.mean(np.concatenate(err_after_real, axis=0)))

    return err_b_n, err_a_n, err_b_r, err_a_r


# 실행 예시
err_b_n, err_a_n, err_b_r, err_a_r = evaluate_policy_effect_with_real_scale_39policy(
    policy_net=policy_net,          # 또는 policy_net_loaded
    quality_model=quality_model,
    dataset=test_ds,
    scaler_y=scaler_y,
    DELTA_MAX_TF=DELTA_MAX_TF,
    n_skip_batches=3,
    n_batches=4
)

print("=== Policy Effect Evaluation (Policy 39D) ===")
print(f"[Normalized]")
print(f"  Mean |error| BEFORE policy : {err_b_n:.6f}")
print(f"  Mean |error| AFTER  policy : {err_a_n:.6f}")
if err_b_n > 1e-12:
    print(f"  Improvement ratio          : {(1 - err_a_n/err_b_n)*100:.2f}%")
else:
    print("  Improvement ratio          : N/A (baseline too small)")

print()
print(f"[Real Residue scale]")
print(f"  Mean |error| BEFORE policy : {err_b_r:.2f} Residue")
print(f"  Mean |error| AFTER  policy : {err_a_r:.2f} Residue")
print(f"  Improvement                : {(err_b_r - err_a_r):.2f} Residue")
# Out:
# === Policy Effect Evaluation (Policy 39D) ===
# [Normalized]
#   Mean |error| BEFORE policy : 0.096709
#   Mean |error| AFTER  policy : 0.062070
#   Improvement ratio          : 35.82%
#
# [Real Residue scale]
#   Mean |error| BEFORE policy : 0.78 Residue
#   Mean |error| AFTER  policy : 0.50 Residue
#   Improvement                : 0.28 Residue

# %%
import joblib

x_scaler = joblib.load("scaler_x_38.pkl")

print("x_scaler.data_min_ :", x_scaler.data_min_)
print("x_scaler.data_max_ :", x_scaler.data_max_)
print("x_scaler.data_range_ :", x_scaler.data_range_)
# Out:
# x_scaler.data_min_ : [ 0.000e+00  0.000e+00  2.740e+02  7.500e+01  0.000e+00  2.000e+00
#   6.500e+01  8.000e+01  5.500e+00  5.500e+00  0.000e+00  9.000e-01
#   9.000e-01  0.000e+00  0.000e+00  7.000e+00 -6.400e+02 -1.900e+01
#  -2.890e+02 -6.940e+02  1.100e+01 -1.000e+00  3.000e+00 -6.100e+01
#  -1.190e+02 -1.580e+02 -4.590e+02 -3.820e+02  2.000e+01 -6.600e+01
#   0.000e+00  1.000e+01  1.200e+02  5.000e-01  0.000e+00  0.000e+00
#   1.376e+02  3.400e+00]
# x_scaler.data_max_ : [ 1.910e+02  1.800e+02  6.960e+02  1.000e+02  8.800e+01  7.500e+01
#   1.312e+03  1.000e+02  1.669e+03  6.700e+01  1.100e+01  1.449e+03
#   5.150e+02  1.510e+02  7.520e+02  8.880e+02  0.000e+00  4.470e+02
#   9.390e+02  8.527e+03  1.769e+03  5.530e+02  6.690e+02  7.320e+02
#   1.405e+03  9.100e+03  0.000e+00 -2.600e+00  7.000e+01  8.810e+02
#   8.740e+02  1.001e+03  2.024e+02  1.570e+01  2.020e+01  1.700e+01
#   2.341e+02  1.150e+01]
# x_scaler.data_range_ : [1.9100000e+02 1.8000000e+02 4.2200000e+02 2.5000000e+01 8.8000000e+01
#  7.3000000e+01 1.2470000e+03 2.0000000e+01 1.6635000e+03 6.1500000e+01
#  1.1000000e+01 1.4481000e+03 5.1409998e+02 1.5100000e+02 7.5200000e+02
#  8.8100000e+02 6.4000000e+02 4.6600000e+02 1.2280000e+03 9.2210000e+03
#  1.7580000e+03 5.5400000e+02 6.6600000e+02 7.9300000e+02 1.5240000e+03
#  9.2580000e+03 4.5900000e+02 3.7939999e+02 5.0000000e+01 9.4700000e+02
#  8.7400000e+02 9.9100000e+02 8.2399994e+01 1.5200000e+01 2.0200001e+01
#  1.7000000e+01 9.6500000e+01 8.1000004e+00]

# %%
y_scaler = joblib.load("scaler_y_1.pkl")

print("y_scaler.data_min_ :", y_scaler.data_min_)
print("y_scaler.data_max_ :", y_scaler.data_max_)
print("y_scaler.data_range_ :", y_scaler.data_range_)
# Out:
# y_scaler.data_min_ : [3.4]
# y_scaler.data_max_ : [11.5]
# y_scaler.data_range_ : [8.1]
