# %%
import sys
import tensorflow as tf

print(f"TensorFlow ver is {tf.__version__}")
print(f"PYTHON ver is {sys.version}")
print("GPU is","available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TensorFlow ver is 2.10.0
# PYTHON ver is 3.9.13 (tags/v3.9.13:6de2ca5, May 17 2022, 16:36:42) [MSC v.1929 64 bit (AMD64)]
# GPU is available

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import joblib
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# ============================================================
# 0) Config
# ============================================================
DATA_DIR = "database"
DATA_FILE = "cmall_remove_duplicate_m_all.csv"   # RAW(정규화 전) csv

QUALITY_MODEL_PATH = "best_model_blaine.h5"      # pretrained quality ANN (frozen)
POLICY_SAVE_PATH   = "best_policy_net.keras"     # save trained policy net (Keras v3)

SCALER_X_PATH = "scaler_x_38.pkl"                # for quality inputs (38)
SCALER_Y_PATH = "scaler_y_1.pkl"                 # for blaine (real unit)

RANDOM_STATE = 42
BATCH_SIZE = 1024
EPOCHS = 500

TARGET_BLAINE_DEFAULT = 3800.0

# Δu bound in normalized space (변수별로 튜닝 권장)
DELTA_MAX_DEFAULT = 0.02

# Loss weights (규제항)
LAM_L2 = 1.0
LAM_L1 = 0.1
HUBER_DELTA = 1.0

LR = 5e-4
PATIENCE = 50

# %%
# ============================================================
# 1) Column definitions
# ============================================================

CONTROL_COLS_9 = [
    "RP_roller_p1",
    "RP_roller_p2",
    "RP_sep_rpm",
    "RP_sep_fan_damper",
    "RP_sep_BF_damper",
    "mill_BF_damper",
    "mill_sep_rpm",
    "mill_sep_fan_damper",
    "grind_aid",
]
assert len(CONTROL_COLS_9) == 9

MONITOR_COLS_28 = [
    # existing monitoring (23)
    "RP_spac",
    "RP_skew",
    "RP_roller_energy1",
    "RP_roller_energy2",
    "RP_roller_vib",
    "RP_BE_energy1",
    "RP_BE_energy2",
    "RP_sep_BF_pressure",
    "dosing_BE_energy",
    "mill_feed_c",
    "mill_feed_cir",
    "mill_energy",
    "mill_in_temp",
    "mill_out_temp",
    "mill_BE_energy",
    "mill_out_gas_temp",
    "mill_out_mater_temp",
    "mill_BF_pressure",
    "mill_sep_BF_pressure",
    "mill_sep_BF_fan_damper",
    "final_BE_1",
    "final_BE_2",
    "final_mater_temp",
    # feed composition moved to monitoring (4)
    "feed_clinker",
    "feed_gypsum",
    "feed_slag",
    "feed_FA",
    # total feed moved to monitoring (1)
    "feed_total",
]
assert len(MONITOR_COLS_28) == 28

# ---- Quality vs Policy 품질 컬럼 분리
QUALITY_PREV_COL   = "blaine_prev"   # quality ANN input
POLICY_CUR_COL     = "blaine"        # policy ANN input (current quality)
TARGET_QUALITY_COL = "blaine_target" # policy ANN input & training target (real unit)

# ---- Quality model input (MUST match pretrained quality model training)
QUALITY_INPUT_COLS = CONTROL_COLS_9 + MONITOR_COLS_28 + [QUALITY_PREV_COL]
assert len(QUALITY_INPUT_COLS) == 38

# ---- Policy input (NOW 39): monitor 28 + current_quality 1 + current_control 9 + target 1
POLICY_INPUT_DIM = 28 + 1 + 9 + 1
assert POLICY_INPUT_DIM == 39

print("QUALITY_INPUT_DIM:", len(QUALITY_INPUT_COLS))
print("POLICY_INPUT_DIM :", POLICY_INPUT_DIM)
# Out:
# QUALITY_INPUT_DIM: 38
# POLICY_INPUT_DIM : 39

# %%
# ============================================================
# 2) Load raw data
# ============================================================
csv_path = os.path.join(DATA_DIR, DATA_FILE)
df = pd.read_csv(csv_path)

# Ensure target column
if TARGET_QUALITY_COL not in df.columns:
    df[TARGET_QUALITY_COL] = TARGET_BLAINE_DEFAULT

required_cols = list(set(
    QUALITY_INPUT_COLS +          # includes blaine_prev
    [POLICY_CUR_COL] +            # includes blaine
    [TARGET_QUALITY_COL]          # includes blaine_target
))

missing_cols = [c for c in required_cols if c not in df.columns]
if missing_cols:
    raise ValueError(f"Missing columns in CSV: {missing_cols}")

df = df.dropna(subset=required_cols).reset_index(drop=True)
print(f"Loaded raw data: {df.shape} from {csv_path}")
print("Target unique count:", df[TARGET_QUALITY_COL].nunique())
# Out:
# Loaded raw data: (60632, 43) from database\cmall_remove_duplicate_m_all.csv
# Target unique count: 1

# %%
# ============================================================
# 3) Split indices
# ============================================================
idx_all = np.arange(len(df))
idx_train, idx_temp = train_test_split(idx_all, test_size=0.30, random_state=RANDOM_STATE)
idx_val, idx_test   = train_test_split(idx_temp, test_size=0.50, random_state=RANDOM_STATE)

print(f"Split: train={len(idx_train)}, val={len(idx_val)}, test={len(idx_test)}")
# Out:
# Split: train=42442, val=9095, test=9095

# %%
# ============================================================
# 4) Fit scalers (train only) & save
# ============================================================

# scaler_x: quality input 38개 (controls+monitor+blaine_prev)
scaler_x = MinMaxScaler(feature_range=(0.0, 1.0))
scaler_x.fit(df.loc[idx_all, QUALITY_INPUT_COLS].to_numpy(dtype=np.float32))

# scaler_y: blaine real unit (policy current/target, and inverse for printing)
scaler_y = MinMaxScaler(feature_range=(0.0, 1.0))
scaler_y.fit(df.loc[idx_all, [POLICY_CUR_COL]].to_numpy(dtype=np.float32))

joblib.dump(scaler_x, SCALER_X_PATH)
joblib.dump(scaler_y, SCALER_Y_PATH)

print("Saved scalers:", SCALER_X_PATH, SCALER_Y_PATH)
# Out:
# Saved scalers: scaler_x_38.pkl scaler_y_1.pkl

# %%
# ============================================================
# 5) Load pretrained quality model (FROZEN)
# ============================================================
quality_model = tf.keras.models.load_model(QUALITY_MODEL_PATH)
quality_model.trainable = False

print("Quality model input/output:", quality_model.input_shape, quality_model.output_shape)
# Out:
# Quality model input/output: (None, 38) (None, 1)

# %%
# ============================================================
# 6) Build normalized arrays for policy training (39(+1)-D)
# ============================================================

# ---- raw arrays
u_cur_raw  = df[CONTROL_COLS_9].to_numpy(dtype=np.float32)            # (N,9)
mon_raw    = df[MONITOR_COLS_28].to_numpy(dtype=np.float32)           # (N,28)
qprev_raw  = df[[QUALITY_PREV_COL]].to_numpy(dtype=np.float32)        # (N,1)  quality prev
qcur_raw   = df[[POLICY_CUR_COL]].to_numpy(dtype=np.float32)          # (N,1)  policy current
yT_raw     = df[[TARGET_QUALITY_COL]].to_numpy(dtype=np.float32)      # (N,1)  policy target

# ---- quality input raw (38): [u_cur, mon, qprev]
Xq_raw = np.concatenate([u_cur_raw, mon_raw, qprev_raw], axis=1)      # (N,38)

# ---- normalize quality input via scaler_x (0~1)
Xq_norm = scaler_x.transform(Xq_raw).astype(np.float32)               # (N,38)
u_cur_norm = Xq_norm[:, :9]                                           # (N,9)
mon_norm   = Xq_norm[:, 9:9+28]                                       # (N,28)
qprev_norm = Xq_norm[:, 9+28:9+28+1]                                  # (N,1) normalized blaine_prev space

# ---- normalize policy current & target via scaler_y (0~1)
qcur_norm = scaler_y.transform(qcur_raw).astype(np.float32)           # (N,1)
yT_norm   = scaler_y.transform(yT_raw).astype(np.float32)             # (N,1)

# ---- policy input (39(+1)):
# [mon_norm(28), qcur_norm(1), u_cur_norm(9), yT_norm(1), qprev_norm(1)]
Xp = np.concatenate([mon_norm, qcur_norm, u_cur_norm, yT_norm, qprev_norm], axis=1).astype(np.float32)
assert Xp.shape[1] == POLICY_INPUT_DIM + 1

# ---- split
Xp_train, yT_train = Xp[idx_train], yT_norm[idx_train]
Xp_val,   yT_val   = Xp[idx_val],   yT_norm[idx_val]
Xp_test,  yT_test  = Xp[idx_test],  yT_norm[idx_test]

print("Policy arrays:",
      "train", Xp_train.shape, yT_train.shape,
      "| val", Xp_val.shape, yT_val.shape,
      "| test", Xp_test.shape, yT_test.shape)
# Out:
# Policy arrays: train (42442, 40) (42442, 1) | val (9095, 40) (9095, 1) | test (9095, 40) (9095, 1)

# %%
# ============================================================
# 7) tf.data datasets
# ============================================================
train_ds = tf.data.Dataset.from_tensor_slices((Xp_train, yT_train)) \
    .shuffle(20000, seed=RANDOM_STATE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((Xp_val, yT_val)) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((Xp_test, yT_test)) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

print("Datasets ready.")
# Out:
# Datasets ready.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout

# ============================================================
# 8) Build policy network (delta-u for 9 controls)
# ============================================================
def build_policy_model(input_shape):
    model = Sequential([
        Dense(256, activation='swish',
              kernel_initializer='glorot_uniform',
              input_shape=input_shape),
        BatchNormalization(),
        Dropout(0.1),

        Dense(256, activation='swish',
              kernel_initializer='glorot_uniform'),
        BatchNormalization(),
        Dropout(0.1),

        Dense(128, activation='swish',
              kernel_initializer='glorot_uniform'),
        BatchNormalization(),

        Dense(9, activation='tanh', name='delta_raw')  # in [-1, 1]
    ])
    return model

policy_net = build_policy_model((POLICY_INPUT_DIM,))
policy_net.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               10240
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  delta_raw (Dense)           (None, 9)                 1161
#
# =================================================================
# Total params: 112,649
# Trainable params: 111,369
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
# ============================================================
# 9) Delta bounds (per-control) in normalized space
# ============================================================
DELTA_MAX = np.array([DELTA_MAX_DEFAULT] * 9, dtype=np.float32)  # (9,)
DELTA_MAX_TF = tf.constant(DELTA_MAX.reshape(1, -1), dtype=tf.float32)

print("DELTA_MAX:", DELTA_MAX)
# Out:
# DELTA_MAX: [0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]

# %%
# ============================================================
# 10) Wrapper model: frozen quality model + trainable policy model
#     Xp layout (40):
#       [mon(28), qcur(1), u_cur(9), y_target(1), qprev(1)]
#     quality input (38):
#       [u_new(9), mon(28), qprev(1)]
# ============================================================
class ControlRecommender(tf.keras.Model):
    def __init__(self, policy_net: tf.keras.Model, quality_model: tf.keras.Model,
                 lam_l2: float = 1.0, lam_l1: float = 0.1, huber_delta: float = 1.0):
        super().__init__()
        self.policy_net = policy_net
        self.quality_model = quality_model  # frozen

        self.lam_l2 = lam_l2
        self.lam_l1 = lam_l1
        self.huber_delta = huber_delta

        self.loss_tracker = tf.keras.metrics.Mean(name="loss")
        self.pred_loss_tracker = tf.keras.metrics.Mean(name="pred_loss")
        self.delta_l2_tracker = tf.keras.metrics.Mean(name="delta_l2")
        self.delta_l1_tracker = tf.keras.metrics.Mean(name="delta_l1")

    @property
    def metrics(self):
        return [self.loss_tracker, self.pred_loss_tracker,
                self.delta_l2_tracker, self.delta_l1_tracker]

    def call(self, Xp_batch, training=False):
        # Xp layout
        mon   = Xp_batch[:, 0:28]
        qcur  = Xp_batch[:, 28:29]    # policy input only (not used in quality input)
        u_cur = Xp_batch[:, 29:38]
        yT    = Xp_batch[:, 38:39]    # policy input only (loss uses yT separately)
        qprev = Xp_batch[:, 39:40]    # IMPORTANT: quality input prev quality

        # policy input: qprev 제외한 39차원만 사용
        Xp_no_prev = Xp_batch[:, 0:39]  # = [mon(28), qcur(1), u_cur(9), yT(1)]

        # policy_net outputs delta_raw in [-1,1]
        delta_raw = self.policy_net(Xp_no_prev, training=training)  # (B,9)
        delta = delta_raw * DELTA_MAX_TF                          # bounded
        u_new = tf.clip_by_value(u_cur + delta, 0.0, 1.0)         # (B,9)

        # quality input (38): [u_new(9), mon(28), qprev(1)]
        Xq_new = tf.concat([u_new, mon, qprev], axis=1)           # (B,38)
        y_pred = self.quality_model(Xq_new, training=False)       # (B,1)

        return u_new, y_pred, delta

    def train_step(self, data):
        Xp_batch, y_target_batch = data

        with tf.GradientTape() as tape:
            _, y_pred, delta = self(Xp_batch, training=True)

            pred_loss = tf.reduce_mean(
                tf.keras.losses.huber(y_target_batch, y_pred, delta=self.huber_delta)
            )

            delta_l2 = tf.reduce_mean(tf.reduce_sum(tf.square(delta), axis=1))
            delta_l1 = tf.reduce_mean(tf.reduce_sum(tf.abs(delta), axis=1))

            loss = pred_loss + self.lam_l2 * delta_l2 + self.lam_l1 * delta_l1

        grads = tape.gradient(loss, self.policy_net.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.policy_net.trainable_variables))

        self.loss_tracker.update_state(loss)
        self.pred_loss_tracker.update_state(pred_loss)
        self.delta_l2_tracker.update_state(delta_l2)
        self.delta_l1_tracker.update_state(delta_l1)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        Xp_batch, y_target_batch = data

        _, y_pred, delta = self(Xp_batch, training=False)

        pred_loss = tf.reduce_mean(
            tf.keras.losses.huber(y_target_batch, y_pred, delta=self.huber_delta)
        )
        delta_l2 = tf.reduce_mean(tf.reduce_sum(tf.square(delta), axis=1))
        delta_l1 = tf.reduce_mean(tf.reduce_sum(tf.abs(delta), axis=1))

        loss = pred_loss + self.lam_l2 * delta_l2 + self.lam_l1 * delta_l1

        self.loss_tracker.update_state(loss)
        self.pred_loss_tracker.update_state(pred_loss)
        self.delta_l2_tracker.update_state(delta_l2)
        self.delta_l1_tracker.update_state(delta_l1)

        return {m.name: m.result() for m in self.metrics}

# %%
# ============================================================
# 11) Train policy (recommender)
# ============================================================
quality_model.trainable = False

recommender = ControlRecommender(
    policy_net=policy_net,
    quality_model=quality_model,
    lam_l2=LAM_L2,
    lam_l1=LAM_L1,
    huber_delta=HUBER_DELTA
)

recommender.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LR))

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=PATIENCE, restore_best_weights=True
)

history = recommender.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[early_stop],
    verbose=1
)

print("\nEvaluation on test set:")
recommender.evaluate(test_ds, verbose=1)

# ---- Save ONLY policy_net (권장)
policy_net.save(POLICY_SAVE_PATH)
print("Saved policy_net to:", POLICY_SAVE_PATH)
# Out:
# Epoch 1/500
# 42/42 [==============================] - 4s 26ms/step - loss: 0.0157 - pred_loss: 0.0083 - delta_l2: 7.4898e-04 - delta_l1: 0.0666 - val_loss: 0.0100 - val_pred_loss: 0.0084 - val_delta_l2: 4.3830e-05 - val_delta_l1: 0.0151
# Epoch 2/500
# 42/42 [==============================] - 1s 17ms/step - loss: 0.0118 - pred_loss: 0.0084 - delta_l2: 1.9989e-04 - delta_l1: 0.0325 - val_loss: 0.0099 - val_pred_loss: 0.0085 - val_delta_l2: 3.4597e-05 - val_delta_l1: 0.0133
# Epoch 3/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0108 - pred_loss: 0.0085 - delta_l2: 9.6357e-05 - delta_l1: 0.0221 - val_loss: 0.0095 - val_pred_loss: 0.0086 - val_delta_l2: 1.8050e-05 - val_delta_l1: 0.0090
# Epoch 4/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0103 - pred_loss: 0.0085 - delta_l2: 5.7257e-05 - delta_l1: 0.0169 - val_loss: 0.0093 - val_pred_loss: 0.0086 - val_delta_l2: 1.1636e-05 - val_delta_l1: 0.0066
# Epoch 5/500
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0099 - pred_loss: 0.0086 - delta_l2: 3.7259e-05 - delta_l1: 0.0135 - val_loss: 0.0092 - val_pred_loss: 0.0086 - val_delta_l2: 9.3661e-06 - val_delta_l1: 0.0062
# Epoch 6/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0097 - pred_loss: 0.0086 - delta_l2: 2.5895e-05 - delta_l1: 0.0112 - val_loss: 0.0091 - val_pred_loss: 0.0086 - val_delta_l2: 6.2474e-06 - val_delta_l1: 0.0050
# Epoch 7/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0096 - pred_loss: 0.0086 - delta_l2: 1.8864e-05 - delta_l1: 0.0095 - val_loss: 0.0090 - val_pred_loss: 0.0086 - val_delta_l2: 4.4782e-06 - val_delta_l1: 0.0038
# Epoch 8/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0095 - pred_loss: 0.0086 - delta_l2: 1.4229e-05 - delta_l1: 0.0082 - val_loss: 0.0090 - val_pred_loss: 0.0086 - val_delta_l2: 3.6618e-06 - val_delta_l1: 0.0031
# Epoch 9/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0094 - pred_loss: 0.0086 - delta_l2: 1.1154e-05 - delta_l1: 0.0072 - val_loss: 0.0090 - val_pred_loss: 0.0087 - val_delta_l2: 2.8374e-06 - val_delta_l1: 0.0031
# Epoch 10/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0093 - pred_loss: 0.0087 - delta_l2: 8.8878e-06 - delta_l1: 0.0064 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 2.2138e-06 - val_delta_l1: 0.0026
# Epoch 11/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0092 - pred_loss: 0.0087 - delta_l2: 7.0834e-06 - delta_l1: 0.0057 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 2.1924e-06 - val_delta_l1: 0.0026
# Epoch 12/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0092 - pred_loss: 0.0087 - delta_l2: 5.9571e-06 - delta_l1: 0.0052 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.9362e-06 - val_delta_l1: 0.0024
# Epoch 13/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0091 - pred_loss: 0.0087 - delta_l2: 4.9420e-06 - delta_l1: 0.0047 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.5713e-06 - val_delta_l1: 0.0023
# Epoch 14/500
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0091 - pred_loss: 0.0087 - delta_l2: 4.2160e-06 - delta_l1: 0.0043 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.6053e-06 - val_delta_l1: 0.0023
# Epoch 15/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0091 - pred_loss: 0.0087 - delta_l2: 3.6545e-06 - delta_l1: 0.0040 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.5245e-06 - val_delta_l1: 0.0023
# Epoch 16/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0090 - pred_loss: 0.0087 - delta_l2: 3.0885e-06 - delta_l1: 0.0036 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.4582e-06 - val_delta_l1: 0.0021
# Epoch 17/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0090 - pred_loss: 0.0087 - delta_l2: 2.7085e-06 - delta_l1: 0.0033 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.8059e-06 - val_delta_l1: 0.0024
# Epoch 18/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0090 - pred_loss: 0.0087 - delta_l2: 2.3606e-06 - delta_l1: 0.0031 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.8606e-06 - val_delta_l1: 0.0024
# Epoch 19/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0090 - pred_loss: 0.0087 - delta_l2: 2.1480e-06 - delta_l1: 0.0029 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 2.0066e-06 - val_delta_l1: 0.0024
# Epoch 20/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0090 - pred_loss: 0.0087 - delta_l2: 1.9352e-06 - delta_l1: 0.0027 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.6560e-06 - val_delta_l1: 0.0023
# Epoch 21/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0090 - pred_loss: 0.0087 - delta_l2: 1.8507e-06 - delta_l1: 0.0026 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.9433e-06 - val_delta_l1: 0.0024
# Epoch 22/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0090 - pred_loss: 0.0087 - delta_l2: 1.7100e-06 - delta_l1: 0.0025 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.5592e-06 - val_delta_l1: 0.0022
# Epoch 23/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.5448e-06 - delta_l1: 0.0023 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.4223e-06 - val_delta_l1: 0.0021
# Epoch 24/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.4431e-06 - delta_l1: 0.0022 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.4031e-06 - val_delta_l1: 0.0019
# Epoch 25/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.4151e-06 - delta_l1: 0.0021 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.3901e-06 - val_delta_l1: 0.0019
# Epoch 26/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.2774e-06 - delta_l1: 0.0020 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.6908e-06 - val_delta_l1: 0.0023
# Epoch 27/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.2906e-06 - delta_l1: 0.0020 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.4116e-06 - val_delta_l1: 0.0019
# Epoch 28/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.2039e-06 - delta_l1: 0.0019 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.5902e-06 - val_delta_l1: 0.0020
# Epoch 29/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.1659e-06 - delta_l1: 0.0018 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.5652e-06 - val_delta_l1: 0.0020
# Epoch 30/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.1620e-06 - delta_l1: 0.0018 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.7223e-06 - val_delta_l1: 0.0021
# Epoch 31/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.1629e-06 - delta_l1: 0.0017 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.2932e-06 - val_delta_l1: 0.0017
# Epoch 32/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.1578e-06 - delta_l1: 0.0017 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.5975e-06 - val_delta_l1: 0.0019
# Epoch 33/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.1646e-06 - delta_l1: 0.0017 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.3481e-06 - val_delta_l1: 0.0017
# Epoch 34/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.1650e-06 - delta_l1: 0.0016 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.3035e-06 - val_delta_l1: 0.0016
# Epoch 35/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.1535e-06 - delta_l1: 0.0016 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.4501e-06 - val_delta_l1: 0.0017
# Epoch 36/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.1943e-06 - delta_l1: 0.0016 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 1.3363e-06 - val_delta_l1: 0.0015
# Epoch 37/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.1901e-06 - delta_l1: 0.0015 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 1.3807e-06 - val_delta_l1: 0.0016
# Epoch 38/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.2987e-06 - delta_l1: 0.0016 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 1.3491e-06 - val_delta_l1: 0.0014
# Epoch 39/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.2540e-06 - delta_l1: 0.0015 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 1.3702e-06 - val_delta_l1: 0.0013
# Epoch 40/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.3636e-06 - delta_l1: 0.0015 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 1.4986e-06 - val_delta_l1: 0.0015
# Epoch 41/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.4290e-06 - delta_l1: 0.0015 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 1.5281e-06 - val_delta_l1: 0.0014
# Epoch 42/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.5439e-06 - delta_l1: 0.0014 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 1.5362e-06 - val_delta_l1: 0.0014
# Epoch 43/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0089 - pred_loss: 0.0087 - delta_l2: 1.6367e-06 - delta_l1: 0.0014 - val_loss: 0.0089 - val_pred_loss: 0.0087 - val_delta_l2: 2.0987e-06 - val_delta_l1: 0.0018
# Epoch 44/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 1.8089e-06 - delta_l1: 0.0015 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 1.8024e-06 - val_delta_l1: 0.0014
# Epoch 45/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 1.9900e-06 - delta_l1: 0.0015 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 1.7748e-06 - val_delta_l1: 0.0015
# Epoch 46/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 2.2105e-06 - delta_l1: 0.0015 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 1.8419e-06 - val_delta_l1: 0.0013
# Epoch 47/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 2.3999e-06 - delta_l1: 0.0014 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 2.1492e-06 - val_delta_l1: 0.0013
# Epoch 48/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 2.6744e-06 - delta_l1: 0.0015 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 2.3715e-06 - val_delta_l1: 0.0013
# Epoch 49/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 3.0989e-06 - delta_l1: 0.0016 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 2.5933e-06 - val_delta_l1: 0.0013
# Epoch 50/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 3.3158e-06 - delta_l1: 0.0016 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 3.2653e-06 - val_delta_l1: 0.0014
# Epoch 51/500
# 42/42 [==============================] - 1s 34ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 3.6684e-06 - delta_l1: 0.0015 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 3.1929e-06 - val_delta_l1: 0.0016
# Epoch 52/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 4.0705e-06 - delta_l1: 0.0015 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 3.2411e-06 - val_delta_l1: 0.0012
# Epoch 53/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 4.4385e-06 - delta_l1: 0.0016 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 4.2392e-06 - val_delta_l1: 0.0015
# Epoch 54/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 4.8924e-06 - delta_l1: 0.0016 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 4.0999e-06 - val_delta_l1: 0.0015
# Epoch 55/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0087 - delta_l2: 5.3067e-06 - delta_l1: 0.0017 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 3.8135e-06 - val_delta_l1: 0.0013
# Epoch 56/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 5.8002e-06 - delta_l1: 0.0017 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 5.1559e-06 - val_delta_l1: 0.0016
# Epoch 57/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 6.2318e-06 - delta_l1: 0.0017 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 4.2096e-06 - val_delta_l1: 0.0012
# Epoch 58/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 6.6821e-06 - delta_l1: 0.0018 - val_loss: 0.0088 - val_pred_loss: 0.0087 - val_delta_l2: 3.8103e-06 - val_delta_l1: 0.0012
# Epoch 59/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 6.9809e-06 - delta_l1: 0.0017 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 5.7109e-06 - val_delta_l1: 0.0015
# Epoch 60/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 7.4214e-06 - delta_l1: 0.0018 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 7.2274e-06 - val_delta_l1: 0.0017
# Epoch 61/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 8.0558e-06 - delta_l1: 0.0018 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 6.0463e-06 - val_delta_l1: 0.0014
# Epoch 62/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 8.5162e-06 - delta_l1: 0.0018 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 5.4040e-06 - val_delta_l1: 0.0014
# Epoch 63/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 8.8438e-06 - delta_l1: 0.0018 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 7.8251e-06 - val_delta_l1: 0.0017
# Epoch 64/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 9.2334e-06 - delta_l1: 0.0019 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 7.9945e-06 - val_delta_l1: 0.0017
# Epoch 65/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.0050e-05 - delta_l1: 0.0019 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 6.7434e-06 - val_delta_l1: 0.0015
# Epoch 66/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.0329e-05 - delta_l1: 0.0019 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 6.7408e-06 - val_delta_l1: 0.0015
# Epoch 67/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.0786e-05 - delta_l1: 0.0019 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 6.1283e-06 - val_delta_l1: 0.0016
# Epoch 68/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.1295e-05 - delta_l1: 0.0020 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.2251e-05 - val_delta_l1: 0.0019
# Epoch 69/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.1619e-05 - delta_l1: 0.0019 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 9.9906e-06 - val_delta_l1: 0.0017
# Epoch 70/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.2163e-05 - delta_l1: 0.0020 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.4950e-05 - val_delta_l1: 0.0022
# Epoch 71/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.2832e-05 - delta_l1: 0.0020 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.1900e-05 - val_delta_l1: 0.0018
# Epoch 72/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.3167e-05 - delta_l1: 0.0020 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.3225e-05 - val_delta_l1: 0.0022
# Epoch 73/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.3383e-05 - delta_l1: 0.0020 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 7.8439e-06 - val_delta_l1: 0.0015
# Epoch 74/500
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.4011e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.3531e-05 - val_delta_l1: 0.0019
# Epoch 75/500
# 42/42 [==============================] - 1s 30ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.4505e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.1107e-05 - val_delta_l1: 0.0019
# Epoch 76/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.5113e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 7.8357e-06 - val_delta_l1: 0.0017
# Epoch 77/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.5278e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.0928e-05 - val_delta_l1: 0.0018
# Epoch 78/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.5802e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.1768e-05 - val_delta_l1: 0.0017
# Epoch 79/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.5884e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 9.6137e-06 - val_delta_l1: 0.0017
# Epoch 80/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.6481e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 9.1507e-06 - val_delta_l1: 0.0016
# Epoch 81/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.6735e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 6.0136e-06 - val_delta_l1: 0.0014
# Epoch 82/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.6889e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.5678e-05 - val_delta_l1: 0.0020
# Epoch 83/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.7259e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.0918e-05 - val_delta_l1: 0.0017
# Epoch 84/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.7548e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.0211e-05 - val_delta_l1: 0.0017
# Epoch 85/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.7704e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.1337e-05 - val_delta_l1: 0.0017
# Epoch 86/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0086 - delta_l2: 1.8126e-05 - delta_l1: 0.0021 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 7.8102e-06 - val_delta_l1: 0.0016
# Epoch 87/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.8245e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 8.4992e-06 - val_delta_l1: 0.0014
# Epoch 88/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.8322e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.2212e-05 - val_delta_l1: 0.0018
# Epoch 89/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.8985e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.0026e-05 - val_delta_l1: 0.0017
# Epoch 90/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.8778e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.1536e-05 - val_delta_l1: 0.0017
# Epoch 91/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.8934e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 9.9345e-06 - val_delta_l1: 0.0016
# Epoch 92/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.9156e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.0581e-05 - val_delta_l1: 0.0016
# Epoch 93/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.9191e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 9.7569e-06 - val_delta_l1: 0.0015
# Epoch 94/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.9347e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 2.6278e-05 - val_delta_l1: 0.0026
# Epoch 95/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 1.9859e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 1.8746e-05 - val_delta_l1: 0.0023
# Epoch 96/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.0085e-05 - delta_l1: 0.0023 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.4775e-05 - val_delta_l1: 0.0019
# Epoch 97/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.0192e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 1.6095e-05 - val_delta_l1: 0.0019
# Epoch 98/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.0283e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 9.4169e-06 - val_delta_l1: 0.0014
# Epoch 99/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.0391e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.1805e-05 - val_delta_l1: 0.0017
# Epoch 100/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.0450e-05 - delta_l1: 0.0022 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 9.6078e-06 - val_delta_l1: 0.0016
# Epoch 101/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.0511e-05 - delta_l1: 0.0023 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.2405e-05 - val_delta_l1: 0.0022
# Epoch 102/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.0724e-05 - delta_l1: 0.0023 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.0695e-05 - val_delta_l1: 0.0016
# Epoch 103/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.1010e-05 - delta_l1: 0.0023 - val_loss: 0.0088 - val_pred_loss: 0.0084 - val_delta_l2: 3.4921e-05 - val_delta_l1: 0.0031
# Epoch 104/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.1140e-05 - delta_l1: 0.0023 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.5755e-05 - val_delta_l1: 0.0020
# Epoch 105/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.1271e-05 - delta_l1: 0.0023 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.1172e-05 - val_delta_l1: 0.0017
# Epoch 106/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.1548e-05 - delta_l1: 0.0023 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.3943e-05 - val_delta_l1: 0.0024
# Epoch 107/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.1600e-05 - delta_l1: 0.0023 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 2.0813e-05 - val_delta_l1: 0.0023
# Epoch 108/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.1691e-05 - delta_l1: 0.0023 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.4172e-05 - val_delta_l1: 0.0018
# Epoch 109/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.2025e-05 - delta_l1: 0.0023 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 1.7061e-05 - val_delta_l1: 0.0021
# Epoch 110/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.1812e-05 - delta_l1: 0.0024 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 1.7884e-05 - val_delta_l1: 0.0022
# Epoch 111/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.2527e-05 - delta_l1: 0.0024 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.1874e-05 - val_delta_l1: 0.0023
# Epoch 112/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.2518e-05 - delta_l1: 0.0024 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 1.6380e-05 - val_delta_l1: 0.0021
# Epoch 113/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.2838e-05 - delta_l1: 0.0023 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 2.3693e-05 - val_delta_l1: 0.0025
# Epoch 114/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.3214e-05 - delta_l1: 0.0024 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.9345e-05 - val_delta_l1: 0.0022
# Epoch 115/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.2963e-05 - delta_l1: 0.0024 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.7746e-05 - val_delta_l1: 0.0026
# Epoch 116/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.3239e-05 - delta_l1: 0.0025 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.4250e-05 - val_delta_l1: 0.0019
# Epoch 117/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.3718e-05 - delta_l1: 0.0025 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 6.3948e-06 - val_delta_l1: 0.0013
# Epoch 118/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.3782e-05 - delta_l1: 0.0025 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.5845e-05 - val_delta_l1: 0.0019
# Epoch 119/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.4012e-05 - delta_l1: 0.0025 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.4699e-05 - val_delta_l1: 0.0019
# Epoch 120/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.4271e-05 - delta_l1: 0.0025 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.1619e-05 - val_delta_l1: 0.0017
# Epoch 121/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.4156e-05 - delta_l1: 0.0025 - val_loss: 0.0088 - val_pred_loss: 0.0084 - val_delta_l2: 3.3577e-05 - val_delta_l1: 0.0032
# Epoch 122/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.4456e-05 - delta_l1: 0.0025 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 1.4828e-05 - val_delta_l1: 0.0019
# Epoch 123/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.4391e-05 - delta_l1: 0.0025 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.2301e-05 - val_delta_l1: 0.0024
# Epoch 124/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.4927e-05 - delta_l1: 0.0025 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.7454e-05 - val_delta_l1: 0.0020
# Epoch 125/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.4881e-05 - delta_l1: 0.0025 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.5905e-05 - val_delta_l1: 0.0020
# Epoch 126/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.4955e-05 - delta_l1: 0.0025 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 1.6621e-05 - val_delta_l1: 0.0022
# Epoch 127/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.5444e-05 - delta_l1: 0.0025 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 8.5560e-06 - val_delta_l1: 0.0015
# Epoch 128/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.5272e-05 - delta_l1: 0.0025 - val_loss: 0.0088 - val_pred_loss: 0.0086 - val_delta_l2: 1.0290e-05 - val_delta_l1: 0.0016
# Epoch 129/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.5752e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.0144e-05 - val_delta_l1: 0.0022
# Epoch 130/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.5125e-05 - delta_l1: 0.0026 - val_loss: 0.0088 - val_pred_loss: 0.0084 - val_delta_l2: 3.0658e-05 - val_delta_l1: 0.0031
# Epoch 131/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.5802e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.7713e-05 - val_delta_l1: 0.0022
# Epoch 132/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.5848e-05 - delta_l1: 0.0025 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.6966e-05 - val_delta_l1: 0.0026
# Epoch 133/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.6030e-05 - delta_l1: 0.0025 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.4732e-05 - val_delta_l1: 0.0020
# Epoch 134/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.6211e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.5704e-05 - val_delta_l1: 0.0025
# Epoch 135/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.6430e-05 - delta_l1: 0.0026 - val_loss: 0.0088 - val_pred_loss: 0.0084 - val_delta_l2: 3.7753e-05 - val_delta_l1: 0.0033
# Epoch 136/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0088 - pred_loss: 0.0085 - delta_l2: 2.6480e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.5529e-05 - val_delta_l1: 0.0020
# Epoch 137/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.6271e-05 - delta_l1: 0.0025 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.2124e-05 - val_delta_l1: 0.0023
# Epoch 138/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.7149e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.0574e-05 - val_delta_l1: 0.0022
# Epoch 139/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.6811e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.6896e-05 - val_delta_l1: 0.0021
# Epoch 140/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.6888e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.3933e-05 - val_delta_l1: 0.0019
# Epoch 141/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0085 - delta_l2: 2.7029e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.4845e-05 - val_delta_l1: 0.0019
# Epoch 142/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.7334e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.4449e-05 - val_delta_l1: 0.0026
# Epoch 143/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.7447e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.7972e-05 - val_delta_l1: 0.0028
# Epoch 144/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.7751e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.3194e-05 - val_delta_l1: 0.0026
# Epoch 145/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.8092e-05 - delta_l1: 0.0027 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 1.3574e-05 - val_delta_l1: 0.0019
# Epoch 146/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.7672e-05 - delta_l1: 0.0026 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 1.5041e-05 - val_delta_l1: 0.0022
# Epoch 147/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.8138e-05 - delta_l1: 0.0027 - val_loss: 0.0088 - val_pred_loss: 0.0084 - val_delta_l2: 2.7269e-05 - val_delta_l1: 0.0029
# Epoch 148/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.8303e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.1104e-05 - val_delta_l1: 0.0023
# Epoch 149/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.8644e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.1249e-05 - val_delta_l1: 0.0022
# Epoch 150/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.8438e-05 - delta_l1: 0.0026 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.2658e-05 - val_delta_l1: 0.0025
# Epoch 151/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.8791e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.2079e-05 - val_delta_l1: 0.0031
# Epoch 152/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.9053e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.9605e-05 - val_delta_l1: 0.0029
# Epoch 153/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.9152e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.3085e-05 - val_delta_l1: 0.0031
# Epoch 154/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.9315e-05 - delta_l1: 0.0027 - val_loss: 0.0088 - val_pred_loss: 0.0085 - val_delta_l2: 1.5969e-05 - val_delta_l1: 0.0021
# Epoch 155/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.9076e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.4517e-05 - val_delta_l1: 0.0026
# Epoch 156/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.9614e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.4218e-05 - val_delta_l1: 0.0026
# Epoch 157/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.9484e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.3351e-05 - val_delta_l1: 0.0019
# Epoch 158/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.9805e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.0579e-05 - val_delta_l1: 0.0029
# Epoch 159/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.9998e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.7622e-05 - val_delta_l1: 0.0028
# Epoch 160/500
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 2.9963e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.7517e-05 - val_delta_l1: 0.0022
# Epoch 161/500
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.0155e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.9535e-05 - val_delta_l1: 0.0022
# Epoch 162/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.0300e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.4655e-05 - val_delta_l1: 0.0018
# Epoch 163/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.0356e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.8377e-05 - val_delta_l1: 0.0027
# Epoch 164/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.0508e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.5176e-05 - val_delta_l1: 0.0019
# Epoch 165/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.0502e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 4.9033e-05 - val_delta_l1: 0.0040
# Epoch 166/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.0492e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.7177e-05 - val_delta_l1: 0.0019
# Epoch 167/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.0475e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.6846e-05 - val_delta_l1: 0.0025
# Epoch 168/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.0734e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.6033e-05 - val_delta_l1: 0.0019
# Epoch 169/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.0671e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.4543e-05 - val_delta_l1: 0.0020
# Epoch 170/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.1099e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.3949e-05 - val_delta_l1: 0.0018
# Epoch 171/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.0937e-05 - delta_l1: 0.0027 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.1914e-05 - val_delta_l1: 0.0024
# Epoch 172/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.1399e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.5941e-05 - val_delta_l1: 0.0026
# Epoch 173/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.1123e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.9825e-05 - val_delta_l1: 0.0021
# Epoch 174/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.1214e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.5018e-05 - val_delta_l1: 0.0018
# Epoch 175/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.1316e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.1949e-05 - val_delta_l1: 0.0025
# Epoch 176/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.1714e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.6928e-05 - val_delta_l1: 0.0020
# Epoch 177/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.1845e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.9835e-05 - val_delta_l1: 0.0021
# Epoch 178/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.1938e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.0536e-05 - val_delta_l1: 0.0021
# Epoch 179/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.1734e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 4.3798e-05 - val_delta_l1: 0.0036
# Epoch 180/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2218e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.3311e-05 - val_delta_l1: 0.0023
# Epoch 181/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2101e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.0854e-05 - val_delta_l1: 0.0022
# Epoch 182/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2290e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 4.0562e-05 - val_delta_l1: 0.0033
# Epoch 183/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2642e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.8645e-05 - val_delta_l1: 0.0021
# Epoch 184/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2651e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.0967e-05 - val_delta_l1: 0.0021
# Epoch 185/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2877e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.0529e-05 - val_delta_l1: 0.0021
# Epoch 186/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2724e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.3304e-05 - val_delta_l1: 0.0030
# Epoch 187/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2890e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.0304e-05 - val_delta_l1: 0.0022
# Epoch 188/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2977e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.5478e-05 - val_delta_l1: 0.0028
# Epoch 189/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2967e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.1573e-05 - val_delta_l1: 0.0029
# Epoch 190/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3008e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.4662e-05 - val_delta_l1: 0.0019
# Epoch 191/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.2921e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 1.5020e-05 - val_delta_l1: 0.0017
# Epoch 192/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3058e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.7561e-05 - val_delta_l1: 0.0025
# Epoch 193/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3050e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.4961e-05 - val_delta_l1: 0.0025
# Epoch 194/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3043e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.2753e-05 - val_delta_l1: 0.0028
# Epoch 195/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3376e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.1779e-05 - val_delta_l1: 0.0028
# Epoch 196/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3491e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 3.9270e-05 - val_delta_l1: 0.0034
# Epoch 197/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3764e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.1370e-05 - val_delta_l1: 0.0027
# Epoch 198/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3491e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.7892e-05 - val_delta_l1: 0.0028
# Epoch 199/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3880e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.5573e-05 - val_delta_l1: 0.0024
# Epoch 200/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3953e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.8955e-05 - val_delta_l1: 0.0025
# Epoch 201/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.3580e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.0283e-05 - val_delta_l1: 0.0022
# Epoch 202/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.4087e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.6779e-05 - val_delta_l1: 0.0025
# Epoch 203/500
# ...
# Epoch 394/500
# 42/42 [==============================] - 1s 31ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9146e-05 - delta_l1: 0.0030 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 4.5629e-05 - val_delta_l1: 0.0033
# Epoch 395/500
# 42/42 [==============================] - 1s 20ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8951e-05 - delta_l1: 0.0030 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.8149e-05 - val_delta_l1: 0.0028
# Epoch 396/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8629e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 4.0130e-05 - val_delta_l1: 0.0029
# Epoch 397/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9081e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.6360e-05 - val_delta_l1: 0.0028
# Epoch 398/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8574e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.0685e-05 - val_delta_l1: 0.0025
# Epoch 399/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8981e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.0857e-05 - val_delta_l1: 0.0029
# Epoch 400/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8970e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0084 - val_delta_l2: 3.3044e-05 - val_delta_l1: 0.0025
# Epoch 401/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8689e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 4.6024e-05 - val_delta_l1: 0.0033
# Epoch 402/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8883e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0082 - val_delta_l2: 5.0453e-05 - val_delta_l1: 0.0034
# Epoch 403/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9067e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.3335e-05 - val_delta_l1: 0.0025
# Epoch 404/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9475e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 3.7185e-05 - val_delta_l1: 0.0029
# Epoch 405/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9242e-05 - delta_l1: 0.0030 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.1968e-05 - val_delta_l1: 0.0030
# Epoch 406/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9028e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.8549e-05 - val_delta_l1: 0.0033
# Epoch 407/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8954e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0085 - val_delta_l2: 2.2022e-05 - val_delta_l1: 0.0020
# Epoch 408/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9134e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.5835e-05 - val_delta_l1: 0.0026
# Epoch 409/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8997e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.7602e-05 - val_delta_l1: 0.0023
# Epoch 410/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9143e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 3.9885e-05 - val_delta_l1: 0.0031
# Epoch 411/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9256e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0084 - val_delta_l2: 2.9730e-05 - val_delta_l1: 0.0024
# Epoch 412/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0083 - delta_l2: 3.8999e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.7119e-05 - val_delta_l1: 0.0027
# Epoch 413/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8951e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.8702e-05 - val_delta_l1: 0.0029
# Epoch 414/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9389e-05 - delta_l1: 0.0030 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.1247e-05 - val_delta_l1: 0.0025
# Epoch 415/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9156e-05 - delta_l1: 0.0030 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.8174e-05 - val_delta_l1: 0.0022
# Epoch 416/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9159e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.9771e-05 - val_delta_l1: 0.0029
# Epoch 417/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9282e-05 - delta_l1: 0.0030 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.1913e-05 - val_delta_l1: 0.0026
# Epoch 418/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9168e-05 - delta_l1: 0.0030 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.1515e-05 - val_delta_l1: 0.0025
# Epoch 419/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9138e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.0706e-05 - val_delta_l1: 0.0025
# Epoch 420/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9200e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0084 - val_delta_l2: 3.0532e-05 - val_delta_l1: 0.0024
# Epoch 421/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9034e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 3.5415e-05 - val_delta_l1: 0.0029
# Epoch 422/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9008e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 3.6973e-05 - val_delta_l1: 0.0030
# Epoch 423/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9127e-05 - delta_l1: 0.0030 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.7932e-05 - val_delta_l1: 0.0024
# Epoch 424/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9260e-05 - delta_l1: 0.0030 - val_loss: 0.0086 - val_pred_loss: 0.0084 - val_delta_l2: 3.1169e-05 - val_delta_l1: 0.0025
# Epoch 425/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9001e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.5838e-05 - val_delta_l1: 0.0022
# Epoch 426/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8980e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.4639e-05 - val_delta_l1: 0.0026
# Epoch 427/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9129e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0082 - val_delta_l2: 5.1061e-05 - val_delta_l1: 0.0034
# Epoch 428/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9168e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0084 - val_delta_l2: 3.2859e-05 - val_delta_l1: 0.0025
# Epoch 429/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9260e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.7682e-05 - val_delta_l1: 0.0028
# Epoch 430/500
# 42/42 [==============================] - 1s 24ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9385e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0084 - val_delta_l2: 2.7272e-05 - val_delta_l1: 0.0022
# Epoch 431/500
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9091e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.3851e-05 - val_delta_l1: 0.0031
# Epoch 432/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9164e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.3553e-05 - val_delta_l1: 0.0032
# Epoch 433/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9409e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.7121e-05 - val_delta_l1: 0.0033
# Epoch 434/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9461e-05 - delta_l1: 0.0030 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.4157e-05 - val_delta_l1: 0.0027
# Epoch 435/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9397e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.4694e-05 - val_delta_l1: 0.0028
# Epoch 436/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9069e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.4134e-05 - val_delta_l1: 0.0026
# Epoch 437/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8964e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.3797e-05 - val_delta_l1: 0.0032
# Epoch 438/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9111e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.3770e-05 - val_delta_l1: 0.0022
# Epoch 439/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0087 - pred_loss: 0.0083 - delta_l2: 3.8982e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.0979e-05 - val_delta_l1: 0.0025
# Epoch 440/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8588e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.6594e-05 - val_delta_l1: 0.0027
# Epoch 441/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9301e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.9275e-05 - val_delta_l1: 0.0028
# Epoch 442/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9584e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.8071e-05 - val_delta_l1: 0.0034
# Epoch 443/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9178e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.7347e-05 - val_delta_l1: 0.0027
# Epoch 444/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9131e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.5815e-05 - val_delta_l1: 0.0031
# Epoch 445/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9494e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.5920e-05 - val_delta_l1: 0.0033
# Epoch 446/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9227e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.9471e-05 - val_delta_l1: 0.0034
# Epoch 447/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9100e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.3647e-05 - val_delta_l1: 0.0026
# Epoch 448/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9663e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0083 - val_delta_l2: 3.5370e-05 - val_delta_l1: 0.0028
# Epoch 449/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9202e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 4.0944e-05 - val_delta_l1: 0.0030
# Epoch 450/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9222e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0084 - val_delta_l2: 3.1773e-05 - val_delta_l1: 0.0024
# Epoch 451/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8477e-05 - delta_l1: 0.0028 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 3.3384e-05 - val_delta_l1: 0.0026
# Epoch 452/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9065e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.3866e-05 - val_delta_l1: 0.0026
# Epoch 453/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.8965e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0084 - val_delta_l2: 3.1888e-05 - val_delta_l1: 0.0024
# Epoch 454/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9197e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.5685e-05 - val_delta_l1: 0.0026
# Epoch 455/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9109e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.8043e-05 - val_delta_l1: 0.0028
# Epoch 456/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9142e-05 - delta_l1: 0.0029 - val_loss: 0.0087 - val_pred_loss: 0.0084 - val_delta_l2: 2.3910e-05 - val_delta_l1: 0.0021
# Epoch 457/500
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9302e-05 - delta_l1: 0.0029 - val_loss: 0.0086 - val_pred_loss: 0.0084 - val_delta_l2: 2.7934e-05 - val_delta_l1: 0.0023
# Epoch 458/500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0086 - pred_loss: 0.0083 - delta_l2: 3.9614e-05 - delta_l1: 0.0030 - val_loss: 0.0086 - val_pred_loss: 0.0083 - val_delta_l2: 3.6832e-05 - val_delta_l1: 0.0028
#
# Evaluation on test set:
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0087 - pred_loss: 0.0084 - delta_l2: 3.5865e-05 - delta_l1: 0.0026
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved policy_net to: best_policy_net.keras

# %%
# ============================================================
# 12) Plot training curves
# ============================================================
hist = history.history

plt.figure(figsize=(10,5))
plt.plot(hist["loss"], label="train total loss")
plt.plot(hist["val_loss"], label="val total loss")
plt.title("Policy training - Total Loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

# pred_loss도 기록되어 있으면 같이 출력
if "pred_loss" in hist:
    plt.figure(figsize=(10,5))
    plt.plot(hist["pred_loss"], label="train pred_loss")
    plt.plot(hist.get("val_pred_loss", []), label="val pred_loss")
    plt.title("Policy training - Prediction Loss (Huber)")
    plt.xlabel("epoch")
    plt.ylabel("pred_loss")
    plt.legend()
    plt.show()

# 규제항도 기록되어 있으면 출력
if "delta_l2" in hist:
    plt.figure(figsize=(10,5))
    plt.plot(hist["delta_l2"], label="train delta_l2")
    plt.plot(hist.get("val_delta_l2", []), label="val delta_l2")
    plt.title("Delta L2")
    plt.xlabel("epoch")
    plt.ylabel("delta_l2")
    plt.legend()
    plt.show()

if "delta_l1" in hist:
    plt.figure(figsize=(10,5))
    plt.plot(hist["delta_l1"], label="train delta_l1")
    plt.plot(hist.get("val_delta_l1", []), label="val delta_l1")
    plt.title("Delta L1")
    plt.xlabel("epoch")
    plt.ylabel("delta_l1")
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 # ============================================================
#       2 # 12) Plot training curves
#       3 # ============================================================
# ----> 4 hist = history.history
#       6 plt.figure(figsize=(10,5))
#       7 plt.plot(hist["loss"], label="train total loss")
#
# NameError: name 'history' is not defined

# %%
# ============================================================
# 13) Quick reload check
# ============================================================
policy_net_loaded = tf.keras.models.load_model(POLICY_SAVE_PATH)
print("Loaded policy_net:", POLICY_SAVE_PATH)
print("Policy output shape:", policy_net_loaded.output_shape)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Loaded policy_net: best_policy_net.keras
# Policy output shape: (None, 9)

# %%
# ------------------------------------------------
# Policy effect check on test samples
# (normalized + real scale)  -- Policy 39D, Xp is 40 (last = qprev)
# ------------------------------------------------
def evaluate_policy_effect_with_real_scale_39policy(
    policy_net,
    quality_model,
    dataset,
    scaler_y,
    DELTA_MAX_TF,
    n_skip_batches=1,
    n_batches=1
):
    err_before_norm = []
    err_after_norm  = []

    err_before_real = []
    err_after_real  = []

    for Xp_batch, y_target_norm in dataset.skip(n_skip_batches).take(n_batches):

        # -------------------------
        # Parse Xp_batch (B,40)
        # layout: [mon(28), qcur(1), u_cur(9), yT(1), qprev(1)]
        # -------------------------
        mon   = Xp_batch[:, 0:28]
        qcur  = Xp_batch[:, 28:29]     # policy input only (not for quality)
        u_cur = Xp_batch[:, 29:38]
        yT    = Xp_batch[:, 38:39]     # policy input only
        qprev = Xp_batch[:, 39:40]     # quality input prev quality

        # -------------------------
        # BEFORE policy (current control)
        # quality input: [u_cur, mon, qprev]  -> (B,38)
        # -------------------------
        Xq_cur = tf.concat([u_cur, mon, qprev], axis=1)
        y_pred_cur_norm = quality_model(Xq_cur, training=False)  # (B,1)

        # -------------------------
        # AFTER policy
        # policy input: first 39 dims only
        # Xp_no_prev = [mon, qcur, u_cur, yT]
        # -------------------------
        Xp_no_prev = Xp_batch[:, 0:39]  # (B,39)
        delta_raw = policy_net(Xp_no_prev, training=False)  # (B,9) in [-1,1]
        delta = delta_raw * DELTA_MAX_TF                    # bounded in normalized space
        u_new = tf.clip_by_value(u_cur + delta, 0.0, 1.0)   # (B,9)

        Xq_new = tf.concat([u_new, mon, qprev], axis=1)     # (B,38)
        y_pred_new_norm = quality_model(Xq_new, training=False)  # (B,1)

        # -------------------------
        # Normalized errors (0~1)
        # -------------------------
        err_b_norm = tf.abs(y_pred_cur_norm - y_target_norm)
        err_a_norm = tf.abs(y_pred_new_norm - y_target_norm)

        err_before_norm.append(err_b_norm.numpy())
        err_after_norm.append(err_a_norm.numpy())

        # -------------------------
        # Real-scale (Blaine) errors
        # -------------------------
        y_target_real   = scaler_y.inverse_transform(y_target_norm.numpy())
        y_pred_cur_real = scaler_y.inverse_transform(y_pred_cur_norm.numpy())
        y_pred_new_real = scaler_y.inverse_transform(y_pred_new_norm.numpy())

        err_b_real = np.abs(y_pred_cur_real - y_target_real)
        err_a_real = np.abs(y_pred_new_real - y_target_real)

        err_before_real.append(err_b_real)
        err_after_real.append(err_a_real)

    # batch들 누적 후 평균
    err_b_n = float(np.mean(np.concatenate(err_before_norm, axis=0)))
    err_a_n = float(np.mean(np.concatenate(err_after_norm, axis=0)))
    err_b_r = float(np.mean(np.concatenate(err_before_real, axis=0)))
    err_a_r = float(np.mean(np.concatenate(err_after_real, axis=0)))

    return err_b_n, err_a_n, err_b_r, err_a_r


# 실행 예시
err_b_n, err_a_n, err_b_r, err_a_r = evaluate_policy_effect_with_real_scale_39policy(
    policy_net=policy_net,          # 또는 policy_net_loaded
    quality_model=quality_model,
    dataset=test_ds,
    scaler_y=scaler_y,
    DELTA_MAX_TF=DELTA_MAX_TF,
    n_skip_batches=3,
    n_batches=4
)

print("=== Policy Effect Evaluation (Policy 39D) ===")
print(f"[Normalized]")
print(f"  Mean |error| BEFORE policy : {err_b_n:.6f}")
print(f"  Mean |error| AFTER  policy : {err_a_n:.6f}")
if err_b_n > 1e-12:
    print(f"  Improvement ratio          : {(1 - err_a_n/err_b_n)*100:.2f}%")
else:
    print("  Improvement ratio          : N/A (baseline too small)")

print()
print(f"[Real Blaine scale]")
print(f"  Mean |error| BEFORE policy : {err_b_r:.2f} Blaine")
print(f"  Mean |error| AFTER  policy : {err_a_r:.2f} Blaine")
print(f"  Improvement                : {(err_b_r - err_a_r):.2f} Blaine")
# Out:
# === Policy Effect Evaluation (Policy 39D) ===
# [Normalized]
#   Mean |error| BEFORE policy : 0.116710
#   Mean |error| AFTER  policy : 0.116393
#   Improvement ratio          : 0.27%
#
# [Real Blaine scale]
#   Mean |error| BEFORE policy : 155.57 Blaine
#   Mean |error| AFTER  policy : 155.15 Blaine
#   Improvement                : 0.42 Blaine
